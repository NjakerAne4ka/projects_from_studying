# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Исследование-объявлений-о-продаже-квартир" data-toc-modified-id="Исследование-объявлений-о-продаже-квартир-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><strong>Исследование объявлений о продаже квартир</strong></a></span></li><li><span><a href="#Откройте-файл-с-данными-и-изучите-общую-информацию." data-toc-modified-id="Откройте-файл-с-данными-и-изучите-общую-информацию.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span><strong>Откройте файл с данными и изучите общую информацию.</strong></a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span><strong>Вывод:</strong></a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span><strong>Предобработка данных</strong></a></span><ul class="toc-item"><li><span><a href="#Сначала-разберусь-с-моментами,-где-что-то-пошло-не-так" data-toc-modified-id="Сначала-разберусь-с-моментами,-где-что-то-пошло-не-так-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Сначала разберусь с моментами, где что-то пошло не так</a></span></li><li><span><a href="#Остались-столбцы-с-нулевыми-значениями-ceiling_height,-living_area,-kitchen_area-и-airports_nearest." data-toc-modified-id="Остались-столбцы-с-нулевыми-значениями-ceiling_height,-living_area,-kitchen_area-и-airports_nearest.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Остались столбцы с нулевыми значениями <em>ceiling_height</em>, <em>living_area</em>, <em>kitchen_area</em> и <em>airports_nearest</em>.</a></span></li><li><span><a href="#Теперь-разберусь-с-оставшимися-двумя-столбцами" data-toc-modified-id="Теперь-разберусь-с-оставшимися-двумя-столбцами-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Теперь разберусь с оставшимися двумя столбцами</a></span></li><li><span><a href="#Смотрю-количество-пропущенных-значений-после-всех-предыдущих-манипуляций." data-toc-modified-id="Смотрю-количество-пропущенных-значений-после-всех-предыдущих-манипуляций.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Смотрю количество пропущенных значений после всех предыдущих манипуляций.</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span><strong>Вывод:</strong></a></span></li></ul></li><li><span><a href="#Посчитайте-и-добавьте-в-таблицу-новые-столбцы" data-toc-modified-id="Посчитайте-и-добавьте-в-таблицу-новые-столбцы-4"><span class="toc-item-num">4&nbsp;&nbsp;</span><strong>Посчитайте и добавьте в таблицу новые столбцы</strong></a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#цену-одного-квадратного-метра-&quot;one_meter_price&quot;" data-toc-modified-id="цену-одного-квадратного-метра-&quot;one_meter_price&quot;-4.0.1"><span class="toc-item-num">4.0.1&nbsp;&nbsp;</span>цену одного квадратного метра "one_meter_price"</a></span></li><li><span><a href="#день-публикации-объявления-&quot;weekday&quot;" data-toc-modified-id="день-публикации-объявления-&quot;weekday&quot;-4.0.2"><span class="toc-item-num">4.0.2&nbsp;&nbsp;</span>день публикации объявления "weekday"</a></span></li><li><span><a href="#месяц-публикации-объявления-&quot;month&quot;" data-toc-modified-id="месяц-публикации-объявления-&quot;month&quot;-4.0.3"><span class="toc-item-num">4.0.3&nbsp;&nbsp;</span>месяц публикации объявления "month"</a></span></li><li><span><a href="#год-публикации-объявления-&quot;year&quot;" data-toc-modified-id="год-публикации-объявления-&quot;year&quot;-4.0.4"><span class="toc-item-num">4.0.4&nbsp;&nbsp;</span>год публикации объявления "year"</a></span></li><li><span><a href="#тип-этажа-квартиры-(значения-—-«первый»,-«последний»,-«другой»),-назову-по-логике-столбик-&quot;floor_type&quot;" data-toc-modified-id="тип-этажа-квартиры-(значения-—-«первый»,-«последний»,-«другой»),-назову-по-логике-столбик-&quot;floor_type&quot;-4.0.5"><span class="toc-item-num">4.0.5&nbsp;&nbsp;</span>тип этажа квартиры (значения — «первый», «последний», «другой»), назову по-логике столбик "floor_type"</a></span></li><li><span><a href="#расстояние-в-км-до-центра-города-&quot;kilometers_rate&quot;" data-toc-modified-id="расстояние-в-км-до-центра-города-&quot;kilometers_rate&quot;-4.0.6"><span class="toc-item-num">4.0.6&nbsp;&nbsp;</span>расстояние в км до центра города "kilometers_rate"</a></span></li></ul></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span><strong>Вывод:</strong></a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных-Ч1" data-toc-modified-id="Исследовательский-анализ-данных-Ч1-5"><span class="toc-item-num">5&nbsp;&nbsp;</span><strong>Исследовательский анализ данных Ч1</strong></a></span><ul class="toc-item"><li><span><a href="#Общую-площадь---используя-данные-по-&quot;total_area&quot;" data-toc-modified-id="Общую-площадь---используя-данные-по-&quot;total_area&quot;-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Общую площадь - используя данные по "total_area"</a></span></li><li><span><a href="#Жилую-площадь---используя-данные-по-&quot;living_area&quot;" data-toc-modified-id="Жилую-площадь---используя-данные-по-&quot;living_area&quot;-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Жилую площадь - используя данные по "living_area"</a></span></li><li><span><a href="#Площадь-кухни---используя-данные-по-&quot;kitchen_area&quot;" data-toc-modified-id="Площадь-кухни---используя-данные-по-&quot;kitchen_area&quot;-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Площадь кухни - используя данные по "kitchen_area"</a></span></li><li><span><a href="#Цена-объекта---используя-данные-по-&quot;last_price&quot;" data-toc-modified-id="Цена-объекта---используя-данные-по-&quot;last_price&quot;-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Цена объекта - используя данные по "last_price"</a></span></li><li><span><a href="#Количество-комнат---используя-данные-по-&quot;rooms&quot;" data-toc-modified-id="Количество-комнат---используя-данные-по-&quot;rooms&quot;-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Количество комнат - используя данные по "rooms"</a></span></li><li><span><a href="#Высота-потолков---используя-данные-по-&quot;ceiling_height&quot;" data-toc-modified-id="Высота-потолков---используя-данные-по-&quot;ceiling_height&quot;-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Высота потолков - используя данные по "ceiling_height"</a></span></li><li><span><a href="#Этаж-квартиры---используя-данные-по-&quot;floor&quot;" data-toc-modified-id="Этаж-квартиры---используя-данные-по-&quot;floor&quot;-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Этаж квартиры - используя данные по "floor"</a></span></li><li><span><a href="#Тип-этажа-квартиры-(«первый»,-«последний»,-«другой»)---используя-данные-по-&quot;floor_type&quot;" data-toc-modified-id="Тип-этажа-квартиры-(«первый»,-«последний»,-«другой»)---используя-данные-по-&quot;floor_type&quot;-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Тип этажа квартиры («первый», «последний», «другой») - используя данные по "floor_type"</a></span></li><li><span><a href="#Общее-количество-этажей-в-доме---используя-данные-по-&quot;floors_total&quot;" data-toc-modified-id="Общее-количество-этажей-в-доме---используя-данные-по-&quot;floors_total&quot;-5.9"><span class="toc-item-num">5.9&nbsp;&nbsp;</span>Общее количество этажей в доме - используя данные по "floors_total"</a></span></li><li><span><a href="#Расстояние-до-центра-города-в-метрах---используя-данные-по-&quot;city_centers_nearest&quot;" data-toc-modified-id="Расстояние-до-центра-города-в-метрах---используя-данные-по-&quot;city_centers_nearest&quot;-5.10"><span class="toc-item-num">5.10&nbsp;&nbsp;</span>Расстояние до центра города в метрах - используя данные по "city_centers_nearest"</a></span></li><li><span><a href="#Расстояние-до-ближайшего-аэропорта---используя-данные-по-&quot;airports_nearest&quot;" data-toc-modified-id="Расстояние-до-ближайшего-аэропорта---используя-данные-по-&quot;airports_nearest&quot;-5.11"><span class="toc-item-num">5.11&nbsp;&nbsp;</span>Расстояние до ближайшего аэропорта - используя данные по "airports_nearest"</a></span></li><li><span><a href="#Расстояние-до-ближайшего-парка---используя-данные-по-&quot;parks_nearest&quot;" data-toc-modified-id="Расстояние-до-ближайшего-парка---используя-данные-по-&quot;parks_nearest&quot;-5.12"><span class="toc-item-num">5.12&nbsp;&nbsp;</span>Расстояние до ближайшего парка - используя данные по "parks_nearest"</a></span></li><li><span><a href="#День-и-месяц-публикации-объявления---используя-данные-по-&quot;weekday&quot;-и-&quot;month&quot;" data-toc-modified-id="День-и-месяц-публикации-объявления---используя-данные-по-&quot;weekday&quot;-и-&quot;month&quot;-5.13"><span class="toc-item-num">5.13&nbsp;&nbsp;</span>День и месяц публикации объявления - используя данные по "weekday" и "month"</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных-Ч2" data-toc-modified-id="Исследовательский-анализ-данных-Ч2-6"><span class="toc-item-num">6&nbsp;&nbsp;</span><strong>Исследовательский анализ данных Ч2</strong></a></span><ul class="toc-item"><li><span><a href="#Изучить,-как-быстро-продавались-квартиры-(столбец-days_exposition).Сколько-дней-«висело»-каждое-объявление." data-toc-modified-id="Изучить,-как-быстро-продавались-квартиры-(столбец-days_exposition).Сколько-дней-«висело»-каждое-объявление.-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Изучить, как быстро продавались квартиры (столбец days_exposition).Сколько дней «висело» каждое объявление.</a></span></li><li><span><a href="#Также,-мне-стало-интересно---а-влияет-ли-количество-фотографий-на-продажу-квартир-(total_images-)." data-toc-modified-id="Также,-мне-стало-интересно---а-влияет-ли-количество-фотографий-на-продажу-квартир-(total_images-).-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Также, мне стало интересно - а влияет ли количество фотографий на продажу квартир (<em>total_images</em> ).</a></span></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-общую-(полную)-стоимость-объекта?" data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-общую-(полную)-стоимость-объекта?-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Какие факторы больше всего влияют на общую (полную) стоимость объекта?</a></span><ul class="toc-item"><li><span><a href="#общей-площади-total_area" data-toc-modified-id="общей-площади-total_area-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>общей площади total_area</a></span></li><li><span><a href="#жилой-площади-living_area" data-toc-modified-id="жилой-площади-living_area-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>жилой площади living_area</a></span></li><li><span><a href="#от-площади-кухни-kitchen_area" data-toc-modified-id="от-площади-кухни-kitchen_area-6.3.3"><span class="toc-item-num">6.3.3&nbsp;&nbsp;</span>от площади кухни kitchen_area</a></span></li><li><span><a href="#от-числа-комнат-rooms" data-toc-modified-id="от-числа-комнат-rooms-6.3.4"><span class="toc-item-num">6.3.4&nbsp;&nbsp;</span>от числа комнат rooms</a></span></li><li><span><a href="#типа-этажа-floor_type" data-toc-modified-id="типа-этажа-floor_type-6.3.5"><span class="toc-item-num">6.3.5&nbsp;&nbsp;</span>типа этажа floor_type</a></span></li><li><span><a href="#даты-размещения-weekday,-month,-year" data-toc-modified-id="даты-размещения-weekday,-month,-year-6.3.6"><span class="toc-item-num">6.3.6&nbsp;&nbsp;</span>даты размещения weekday, month, year</a></span></li></ul></li><li><span><a href="#Посчитать-среднюю-цену-одного-квадратного-метра-в-10-населённых-пунктах-с-наибольшим-числом-объявлений." data-toc-modified-id="Посчитать-среднюю-цену-одного-квадратного-метра-в-10-населённых-пунктах-с-наибольшим-числом-объявлений.-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Посчитать среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений.</a></span></li><li><span><a href="#Ранее-было-посчитано-расстояние-до-центра-в-километрах." data-toc-modified-id="Ранее-было-посчитано-расстояние-до-центра-в-километрах.-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Ранее было посчитано расстояние до центра в километрах.</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-7"><span class="toc-item-num">7&nbsp;&nbsp;</span><strong>Общий вывод</strong></a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-8"><span class="toc-item-num">8&nbsp;&nbsp;</span><strong>Чек-лист готовности проекта</strong></a></span></li></ul></div>

# %% [markdown]
# ## __Исследование объявлений о продаже квартир__
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.
#
# <div style="border:solid Purple 2px; padding: 40px">
#
#
#
# __Входные данные от сервиса Яндекс Недвижимость__ архив объявлений за несколько лет о продаже квартир в Санкт-Петербурге и соседних населённых пунктах.
#
# _Данные состоят из:_
#
# * _airports_nearest_ — расстояние до ближайшего аэропорта в метрах (м)
# * _balcony_ — число балконов
# * _ceiling_height_ — высота потолков (м)
# * _cityCenters_nearest_ — расстояние до центра города (м)
# * _days_exposition_ — сколько дней было размещено объявление (от публикации до снятия)
# * _first_day_exposition_ — дата публикации
# * _floor_ — этаж
# * _floors_total_ — всего этажей в доме
# * _is_apartment_ — апартаменты (булев тип)
# * _kitchen_area_ — площадь кухни в квадратных метрах (м²)
# * _last_price_ — цена на момент снятия с публикации
# * _living_area_ — жилая площадь в квадратных метрах (м²)
# * _locality_name_ — название населённого пункта
# * _open_plan_ — свободная планировка (булев тип)
# * _parks_around3000_ — число парков в радиусе 3 км
# * _parks_nearest_ — расстояние до ближайшего парка (м)
# * _ponds_around3000_ — число водоёмов в радиусе 3 км
# * _ponds_nearest_ — расстояние до ближайшего водоёма (м)
# * _rooms_ — число комнат
# * _studio_ — квартира-студия (булев тип)
# * _total_area_ — общая площадь квартиры в квадратных метрах (м²)
# * _total_images_ — число фотографий квартиры в объявлении
#
# __Целью проекта является__
#
# выполнить предобработку данных и изучить их, чтобы найти интересные особенности и зависимости, которые существуют на рынке недвижимости.
#
#
#          ______________________________________________План работы______________________________________________
#
# _1. Открыть и изучить общую информацию о данных_
#
# _2. Предобработка данных_
#
# * Изучить базу данных на наличие ошибок, пропусков, дубликатов и аномалий
# * Если есть - исправить
# * Учитывая большой объём данных, необходимо проверить - надо ли их категоризировать для большего удобства в анализе
# * Добавить в таблицу новые столбцы со следующими параметрами:
#
#     * __ценой одного квадратного метра --__ "one_meter_price";
#     * __днём недели публикации объявления --__ 0 — понедельник, 1 — вторник и так далее;
#     * __месяцем публикации объявления --__ "month";
#     * __годом публикации объявления --__ "year";
#     * __типом этажа квартиры --__ значения — «первый», «последний», «другой»;
#     * __расстоянием до центра города в километрах (перевести из м в км и округлить до целых значений) --__ "kilometers_rate".
#
#
#
# _3. Ислледование данных. Учитывая большой объём необходимо ответить на возникшие вопросы:_
#
# * Изучить, как быстро продавались квартиры (столбец days_exposition).
# * Какие продажи можно считать быстрыми, а какие — необычно долгими?
# * Какие факторы больше всего влияют на общую (полную) стоимость объекта?
# * Посчитать среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделить населённые пункты с самой высокой и низкой стоимостью квадратного метра.
# * Выделить квартиры в Санкт-Петербурге (с помощью столбца locality_name) и вычислить среднюю цену каждого километра. Описать, как стоимость объектов зависит от расстояния до центра города.
#
# _4. Сделать общий вывод по полученным и просмотренным данным на основе цели_
#
# </div>

# %% [markdown]
# ## __Откройте файл с данными и изучите общую информацию.__

# %%
import pandas as pd # импортирую библиотеку pandas
import seaborn as sns # в будущем понадобилось
import numpy as np # в будущем понадобилось
import matplotlib.pyplot as plt # в будущем понадобилось
import scipy.stats as stats
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t' )# прочитываю csv-файл
def printing_needable_from_data(data):
    return (display(data.head(15)), print(),
            display(data.tail(15)),  print(),
            print(data.info()), print(),
            print('\nДубликатов найдено:', data.duplicated().sum()), print(),
            print(data.isnull().sum())
           )
printing_needable_from_data(data)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9             18   5400000.0       61.00  2017-02-26T00:00:00      3
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# ...

# %%
data.hist(figsize=(15, 20), color = 'green');

# %%
colours = ['#00992b', '#d6e3b1'] 
sns.heatmap(data.isnull(), cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### **Вывод:**
#
# __Записей__ много, но уже можно отметить, что нет явных дубликатов, есть столбцы, где всё выглядит на первый взгляд как надо, есть где - наоборот.
#
# __Есть столбцы где, на первый взгляд, всё в порядке__
#
# _0   total_images          23699 non-null  int64_ __Целые числа__ +
#
# _1   last_price            23699 non-null  float64_ __Числа с плавающей точкой.__ +
#
# _2   total_area            23699 non-null  float64_ __Числа с плавающей точкой.__ +
#
# _4   rooms                 23699 non-null  int64_ __Целые числа__ +
#
# _6   floors_total          23613 non-null  float64_ __Числа с плавающей точкой.__ +
#
# _8   floor                 23699 non-null  int64_ __Целые числа__ +
#
# _10  studio                23699 non-null  bool_ __Булевое значение, вроде всё норм__ +
#
# _11  open_plan             23699 non-null  bool_ __Булевое значение, вроде всё норм__ +
#
# _14  locality_name         23650 non-null  object_
#
# __На первый взгляд всё в порядке, но нужно будет проверить обозначения названий населённых пунктов - вдруг там есть похожие названия про одно и тоже, но написанные по-разному__ +
#
# __Но также есть столбцы с рядом проблем, которые необходимо устранить (по возможности) для удобного и адекватного анализа.__
#
# _3   first_day_exposition 23699 non-null object_ - это же дата, должен быть тип __datetime__, хотя в самой таблице отображаются даты, к тому же - часы и минуты не нужны - они не указаны, значит их надо убрать
#
# _5   ceiling_height 14504 non-null float64_ - есть нулевые значения __NaN__ - это нехорошо
#
# _7   living_area 21796 non-null float64_ - есть нулевые значения __NaN__
#
# _9   is_apartment 2775 non-null object_  - есть нулевые значения __NaN__ и __False__ - надо разобраться что к чему
#
# _12  kitchen_area 21421 non-null float64_ - есть нулевые значения __NaN__
#
# _13  balcony 12180 non-null float64_ - есть нулевые значения __NaN__, думаю, что лучше его сделать __int__, потому что указано только количество, в данном случае __float__ не верный тип данных
#
# _15  airports_nearest      18157 non-null  float64_ - есть нулевые значения __NaN__
#
# _16  cityCenters_nearest   18180 non-null  float64_ - есть нулевые значения __NaN__, мне ещё не нравится название - хочу переделать в красивое
#
# _17  parks_around3000      18181 non-null  float64_  - есть нулевые значения __NaN__, тип скорее должен быть __int__, потому что указано конкретное количество парков
#
# _18  parks_nearest         8079 non-null   float64_ - также как и с __parks_around3000__
#
# _19  ponds_around3000      18181 non-null  float64_ - также как и с __parks_around3000__ (только про пруды)
#
# _20  ponds_nearest         9110 non-null   float64_ - также как и с __parks_around3000__ (только про пруды)
#
# _21  days_exposition       20518 non-null  float64_ - также как и с __parks_around3000__ (только про дни размещения объявления)
#
#                                     Для работы с данными сначала надо пофиксить эти проблемы (какие возможно)

# %% [markdown]
# ## __Предобработка данных__

# %% [markdown]
# ### Сначала разберусь с моментами, где что-то пошло не так

# %% [markdown]
# _3   first_day_exposition 23699 non-null object_ - должен быть тип __datetime__, так что, меняю.

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'])
# print(data['first_day_exposition']) #принтом проверяю, что всё работает как надо и поменялся формат
# ура! всё красивое. можно закомментить
print(data['first_day_exposition'].value_counts())
# Out:
# 2018-02-01    368
# 2017-11-10    240
# 2017-10-13    124
# 2017-09-27    111
# 2018-03-26     97
#              ...
# 2015-05-17      1
# 2017-01-06      1
# 2016-12-30      1
# 2016-07-06      1
# 2015-03-27      1
# Name: first_day_exposition, Length: 1491, dtype: int64

# %% [markdown]
# Теперь можно разобраться с другими "неправильными" форматами. Проблемы были замечены в _balcony_, _parks_around3000_, _parks_nearest_, _ponds_around3000_, _ponds_nearest_ и _days_exposition_. Во всех перечисленных необходимо изменить тип данных и разобраться с нулевыми значениями (потому что если с ними не разобраться, то и изменить тип данных не получиться)
#
# Надо ещё воспользоваться value_counts, чтобы позже воспользоватсья данными по отдельным столбцам (для понимания аномалий, выбросов и прочего)

# %%
# скорее всего, если нет информации по балконам, то их просто нет, поэтому пусть будет 0
data['balcony'] = data['balcony'].fillna(0).astype('int') 
print(data['balcony'].describe())
print()
print(data['balcony'].value_counts())
# Out:
# count    23699.000000
# mean         0.591080
# std          0.959298
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          5.000000
# Name: balcony, dtype: float64
#
# 0    15277
# 1     4195
# 2     3659
# 5      304
# 4      183
# 3       81
# Name: balcony, dtype: int64

# %%
data['parks_around3000'] = data['parks_around3000'].fillna(0).astype('int') # если информации нет, значит их просто нет, поэтому пусть будет 0
print(data['parks_around3000'].describe())
print()
print(data['parks_around3000'].value_counts())
# Out:
# count    23699.000000
# mean         0.469049
# std          0.748534
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          3.000000
# Name: parks_around3000, dtype: float64
#
# 0    15624
# 1     5681
# 2     1747
# 3      647
# Name: parks_around3000, dtype: int64

# %%
# если поставить 0, то выпадет огромное количество данных, поэтому оставлю всё как есть
print(data['parks_nearest'].describe())
print()
print(data['parks_nearest'].value_counts())
# Out:
# count    8079.000000
# mean      490.804555
# std       342.317995
# min         1.000000
# 25%       288.000000
# 50%       455.000000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64
#
# 441.0     67
# 392.0     41
# 173.0     41
# 456.0     40
# 471.0     32
#           ..
# 2489.0     1
# 786.0      1
# 793.0      1
# 92.0       1
# 929.0      1
# Name: parks_nearest, Length: 995, dtype: int64

# %%
data['ponds_around3000'] = data['ponds_around3000'].fillna(0).astype('int') # если информации нет, значит их просто нет, поэтому пусть будет 0
print(data['ponds_around3000'].describe())
print()
print(data['ponds_around3000'].value_counts())
# Out:
# count    23699.000000
# mean         0.590911
# std          0.883999
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          3.000000
# Name: ponds_around3000, dtype: float64
#
# 0    14589
# 1     5717
# 2     1892
# 3     1501
# Name: ponds_around3000, dtype: int64

# %%
# если поставить 0, то выпадеть огромное количество данных, UPD поэтому меняю только формат записей на инт
data['ponds_nearest'] = np.floor(pd.to_numeric(data['ponds_nearest'], errors='coerce')).astype('Int64')
print(data['ponds_nearest'].describe())
print()
print(data['ponds_nearest'].value_counts())
# Out:
# count    9110.000000
# mean      517.980900
# std       277.720643
# min        13.000000
# 25%       294.000000
# 50%       502.000000
# 75%       729.000000
# max      1344.000000
# Name: ponds_nearest, dtype: float64
#
# 427     70
# 454     41
# 153     40
# 433     39
# 474     37
#         ..
# 948      1
# 1023     1
# 884      1
# 967      1
# 188      1
# Name: ponds_nearest, Length: 1096, dtype: Int64

# %%
# UPD 0 означает, что квартира не продана, поэтому нули надо сохранить, меняю только тип данных
#data['days_exposition'] = np.floor(pd.to_numeric(data['days_exposition'], errors='coerce')).astype('Int64')
print(data['days_exposition'].describe())
print()
print(data['days_exposition'].value_counts())
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64
#
# 45.0      880
# 60.0      538
# 7.0       234
# 30.0      208
# 90.0      204
#          ...
# 969.0       1
# 1.0         1
# 1147.0      1
# 1148.0      1
# 1174.0      1
# Name: days_exposition, Length: 1141, dtype: int64

# %% [markdown]
# ### Остались столбцы с нулевыми значениями _ceiling_height_, _living_area_, _kitchen_area_ и _airports_nearest_.
#
# Также есть столбцы
# * _is_apartment_ - надо разобраться как в нём указать какие помещения - прям квартиры, а какие апартаменты
# * _cityCenters_nearest_, где название в некрасивом регистре и его надо бы сменить на нормальный регистр, а ткаже есть проблема с пропуском данных

# %% [markdown]
# Сначала разберусь с колонкой _ceiling_height_

# %% [markdown]
# ceiling_height, last_price, total_area_rooms

# %%
print(data['ceiling_height'].sort_values().plot(y = 'ceiling_height', color = 'green', kind = 'hist', bins = 30, range=(2,5)))
data['ceiling_height'].fillna(data['ceiling_height'].median(), inplace=True);
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Проверяю на аномалии

# %%
data['ceiling_height'].plot(kind='box')
plt.show()

# %%
data['last_price'].fillna(data['last_price'].median(), inplace=True)

# %% [markdown]
# Проверяю на аномалии

# %%
data['last_price'].plot(kind='box')
plt.show()

# %%
data['total_area'].fillna(data['total_area'].median(), inplace=True)
data['total_area'].plot(kind='box')
plt.show()

# %%
data['rooms'].fillna(data['rooms'].median(), inplace=True)
data['rooms'].plot(kind='box')
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Методом межквартильного диапазона определю и удалю выбросы.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Я тут покумекала, полдня думала и сделала фукцию для отбрасывания значений в 1.5 размаха, но чтобы не сильно много данных потерялось, ну и чтобы не страдать - потому что 100500 строчек одинаковых писать надоело Ж)
# </div>

# %% [markdown]
# __Было__

# %%
#код ревьюера взяла навооружение, чтобы можно было проверять дату на количество утерянных данных в будущем
data2 = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
data.shape[0] / data2.shape[0]
# Out:
# 1.0

# %%
# Функция для подсчёта границ с учетом 1.5 размаха
def quartile_range(df, column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    dfq = df.loc[(df[column] < q3 + 1.5*iqr) & (df[column] > q1 - 1.5*iqr), column]
    return dfq

# %%
# Столбцы с выбросами
list_features = ['ceiling_height', 'last_price', 'total_area', 'rooms']
for col in list_features:
    data[col] = quartile_range(data, col)

# %% [markdown]
# __Стало__

# %%
data.shape[0] / data2.shape[0]
# Out:
# 1.0

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.163800e+04  22459.000000  23504.000000    20727.000000
# mean       9.858475  4.839970e+06     54.364907      2.030250        2.631264
# std        5.682529  2.217341e+06     19.385325      0.973667        0.081300
# min        0.000000  1.219000e+04     12.000000      0.000000        2.460000
# 25%        6.000000  3.300000e+06     39.400000      1.000000        2.600000
# 50%        9.000000  4.400000e+06     50.100000      2.000000        2.650000
# 75%       14.000000  6.000000e+06     65.600000      3.000000        2.650000
# max       50.000000  1.189440e+07    114.600000      5.000000        2.850000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  23699.000000
# mean      10.673824     34.457852      5.892358     10.569807      0.591080
# ...

# %%
data['ceiling_height'].plot(kind='box')
plt.show()
data['ceiling_height'].hist(color = 'green');

# %%
print(data['ceiling_height'].describe())
print()
print(data['ceiling_height'].value_counts().head())
# Out:
# count    20727.000000
# mean         2.631264
# std          0.081300
# min          2.460000
# 25%          2.600000
# 50%          2.650000
# 75%          2.650000
# max          2.850000
# Name: ceiling_height, dtype: float64
#
# 2.65    9871
# 2.50    3515
# 2.60    1646
# 2.70    1574
# 2.80     993
# Name: ceiling_height, dtype: int64

# %% [markdown]
# __last_price — цена на момент снятия с публикации__

# %%
data['last_price'].plot(kind='box')
plt.show()
data['last_price'].hist(color = 'green');

# %%
print(data['last_price'].describe())
print()
print(data['last_price'].value_counts().head())
# Out:
# count    2.163800e+04
# mean     4.839970e+06
# std      2.217341e+06
# min      1.219000e+04
# 25%      3.300000e+06
# 50%      4.400000e+06
# 75%      6.000000e+06
# max      1.189440e+07
# Name: last_price, dtype: float64
#
# 4500000.0    342
# 3500000.0    291
# 4000000.0    260
# 4300000.0    260
# 4200000.0    259
# Name: last_price, dtype: int64

# %% [markdown]
# __total_area — общая площадь квартиры в квадратных метрах (м²)__

# %%
data['total_area'].plot(kind='box')
plt.show()
data['total_area'].hist(color = 'green');

# %%
print(data['total_area'].describe())
print()
print(data['total_area'].value_counts().head())
# Out:
# count    22459.000000
# mean        54.364907
# std         19.385325
# min         12.000000
# 25%         39.400000
# 50%         50.100000
# 75%         65.600000
# max        114.600000
# Name: total_area, dtype: float64
#
# 45.0    419
# 42.0    383
# 60.0    347
# 31.0    346
# 44.0    345
# Name: total_area, dtype: int64

# %% [markdown]
# __rooms — число комнат__

# %%
data['last_price'].plot(kind='box')
plt.show()
data['last_price'].hist(color = 'green');

# %%
print(data['rooms'].describe())
print()
print(data['rooms'].value_counts().head())
# Out:
# count    23504.000000
# mean         2.030250
# std          0.973667
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          5.000000
# Name: rooms, dtype: float64
#
# 1.0    8047
# 2.0    7940
# 3.0    5814
# 4.0    1180
# 5.0     326
# Name: rooms, dtype: int64

# %%
# print(data['living_area'].sort_values().plot(y = 'living_area', color = 'green', kind = 'hist', bins = 5))
# print()
print(data['living_area'].describe())
print()
print(data['living_area'].value_counts().head())
data['living_area'].plot(kind='box')
plt.show()
data['living_area'].hist(bins=5 , color = 'green');
# Out:
# count    21796.000000
# mean        34.457852
# std         22.030445
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64
#
# 18.0    882
# 17.0    675
# 30.0    598
# 16.0    486
# 20.0    481
# Name: living_area, dtype: int64

# %%
data['living_area'].hist(bins=5 , color = 'green', range=(60, 100));

# %%
print(data['kitchen_area'].describe())
print()
print(data['kitchen_area'].value_counts().head())
data['kitchen_area'].plot(kind='box')
plt.show()
data['kitchen_area'].hist(bins=5 , color = 'green');
# Out:
# count    21421.000000
# mean        10.569807
# std          5.905438
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64
#
# 6.0     1300
# 10.0    1262
# 8.0     1110
# 9.0     1101
# 7.0     1062
# Name: kitchen_area, dtype: int64

# %%
data['kitchen_area'].hist(bins=5 , color = 'green', range=(30, 60));

# %%
print(data['airports_nearest'].describe())
print()
print(data['airports_nearest'].value_counts())
data['airports_nearest'].plot(kind='box')
plt.show()
data['airports_nearest'].hist(bins=5 , color = 'green');
# Out:
# count    18157.000000
# mean     28793.672193
# std      12630.880622
# min          0.000000
# 25%      18585.000000
# 50%      26726.000000
# 75%      37273.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64
#
# 37434.0    61
# 21928.0    32
# 39946.0    30
# 44870.0    30
# 18732.0    27
#            ..
# 53478.0     1
# 20335.0     1
# 33699.0     1
# 26945.0     1
# 20875.0     1
# Name: airports_nearest, Length: 8275, dtype: int64

# %%
data['airports_nearest'].hist(bins=5 , color = 'green', range=(70000, 90000));

# %% [markdown]
# ### Теперь разберусь с оставшимися двумя столбцами

# %% [markdown]
# __is_apartment__: _False_ это жилая квартира, а _True_ - не жилая или же другого типа квартира (как гостиница, хостел и прочее)? Может быть - _NaN_ значения появились из-за того, что их "вбили" в базу позже? попробую заменить всё на "False" и буду считать, что это - квартиры.

# %%
data['is_apartment'] = data['is_apartment'].fillna(value=False)
print(data['is_apartment'].head())
print()
print(data['is_apartment'].describe())
print()
print(data['is_apartment'].value_counts())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: is_apartment, dtype: bool
#
# count     23699
# unique        2
# top       False
# freq      23649
# Name: is_apartment, dtype: object
#
# False    23649
# True        50
# Name: is_apartment, dtype: int64

# %% [markdown]
# Выходит 23699 квартиры и 50 - помещения другого типа (те же апартаменты). Нашлось два уникальных объекта!

# %% [markdown]
# Сначала переименую _cityCenters_nearest_ в _city_centers_nearest_, а потом всё остальное

# %%
data.rename(columns = {'cityCenters_nearest':'city_centers_nearest'}, inplace = True)
print(data['city_centers_nearest'].head()) # красивое, но не совсем
print()
print(data['city_centers_nearest'].describe())
print()
print(data['city_centers_nearest'].value_counts())
# Out:
# 0    16028.0
# 1    18603.0
# 2    13933.0
# 3     6800.0
# 4     8098.0
# Name: city_centers_nearest, dtype: float64
#
# count    18180.000000
# mean     14191.277833
# std       8608.386210
# min        181.000000
# 25%       9238.000000
# 50%      13098.500000
# 75%      16293.000000
# max      65968.000000
# Name: city_centers_nearest, dtype: float64
#
# 8460.0     61
# 20802.0    32
# 10720.0    30
# 8434.0     27
# 20444.0    27
#            ..
# 5278.0      1
# 11575.0     1
# 3205.0      1
# 12747.0     1
# 4234.0      1
# Name: city_centers_nearest, Length: 7642, dtype: int64

# %% [markdown]
# ### Смотрю количество пропущенных значений после всех предыдущих манипуляций.

# %% [markdown]
# Было вот так
#                             ![image-4.png](attachment:image-4.png)
#                             ![image-3.png](attachment:image-3.png)
#
# А стало:

# %%
display(data.head(15))
print()
print(data.isnull().sum())
print()
colours = ['#00992b', '#d6e3b1'] 
sns.heatmap(data.isnull(), cmap=sns.color_palette(colours))
print() # составляю список недостающих записей для каждого признака
for i in data.columns:
    pct_missing = np.mean(data[i].isnull())
    print('{} - {}%'.format(i, round(pct_missing*100)))
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20         NaN      108.00           2019-03-07    3.0
# 1              7   3350000.0       40.40           2018-12-04    1.0
# 2             10   5196000.0       56.00           2015-08-20    2.0
# 3              0         NaN         NaN           2015-07-24    3.0
# 4              2  10000000.0      100.00           2018-06-19    2.0
# 5             10   2890000.0       30.40           2018-09-10    1.0
# 6              6   3700000.0       37.30           2017-11-02    1.0
# 7              5   7915000.0       71.60           2019-04-18    2.0
# 8             20   2900000.0       33.16           2018-05-23    1.0
# 9             18   5400000.0       61.00           2017-02-26    3.0
# 10             5   5050000.0       39.60           2017-11-16    1.0
# 11             9   3300000.0       44.00           2018-08-27    2.0
# 12            10   3890000.0       54.00           2016-06-30    2.0
# ...

# %% [markdown]
# Стало намного лучше, но есть куда стремиться дальше. Остались проблемы с _floors_total_, _living_area_, _kitchen_area_, _locality_name_, _airports_nearest_ и _city_centers_nearest_ (там у нас оставались нулевые значения).
#
# Попробую решить.
#
# Может, в __living_area 8%__ (жилая площадь в квадратных метрах (м²)) заменить пропуски на медианные по всему из столбцу (не считая нулевые, естественно)?
#
# __kitchen_area 10%__ (площадь кухни в квадратных метрах (м²)). Тут, скорее всего, надо проделать тоже самое, что и с жилой площадью.
#
# __locality_name 0%__ (название населённого пункта) надо отдельно просмотреть данные, выделить основные названия и прописать что-нибудь типа функции на замену повторов или дубликатов или ещё что-нибудь придумать.
#
# __airports_nearest 28%__ (расстояние до ближайшего аэропорта в метрах (м)), может стоит проверить - а есть ли в населённых пунктах вообще доступ к аеропорту? Тут больше всего пропущенных записей
#
# __city_centers_nearest 28%__ (расстояние до центра города (м)) - может пропуски это не города вообще? Тогда как мне их определить? тут, как и с аэропортами - может это связано?

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> <b>UPD</b>
#
# <b>parks_nearest - 72%</b> (парки, находящиеся поблизости от квартиры) надо просмотреть их - что там не так.
#
# <b>ponds_nearest - 67%</b> (водоёмы, находящиеся поблизости от квартиры) - ничего себе, - тоже надо туда заглянуть!
#
# <b>days_exposition - 11%</b> (сколько по времени находится публикация) нужно будет проверить </div>

# %% [markdown]
# __living_area (жилая площадь в квадратных метрах (м²))__

# %%
# print(data['living_area'].describe())
# print(data['living_area'].isnull().sum())
#очень много пропущенных данных 1870, лучше заменить их на среднее, как в том уроке с ..._ratio
# поделю жилую площадь на общую, а потом их помножу чтобы вывести среднее для заполнения пропусков
living_area_ratio = data['living_area'].mean() / data['total_area']
data['living_area'].fillna(living_area_ratio * data['total_area'], inplace=True)
print(data['living_area'].isnull().sum()) #ура
print()
print(data['living_area'].describe())
# Out:
# 129
#
# count    23570.000000
# mean        34.457852
# std         21.185130
# min          2.000000
# 25%         19.000000
# 50%         31.000000
# 75%         41.300000
# max        409.700000
# Name: living_area, dtype: float64

# %% [markdown]
# Медиана и среднее теперь не слишком отличаются, работаем дальше

# %% [markdown]
# __kitchen_area (площадь кухни в квадратных метрах (м²))__

# %%
# print(data['kitchen_area'].describe())
# print(data['kitchen_area'].isnull().sum())
# Божечки-кошечки! А тут ещё больше! 2231!
# думаю, что тут надо решать по аналогии с жилой площадью
kitchen_area_ratio = data['kitchen_area'].mean() / data['total_area']
data['kitchen_area'].fillna(kitchen_area_ratio * data['total_area'], inplace=True)
print(data['kitchen_area'].isnull().sum()) #ура
# Out:
# 113

# %% [markdown]
# __locality_name (название населённого пункта)__

# %% [markdown]
# Проверю _locality_name_ на неявные дубликаты (что я хотела сделать раньше, но отложила)

# %%
unique_locality_name = data['locality_name']
print(unique_locality_name.sort_values().unique())
# Out:
# ['Бокситогорск' 'Волосово' 'Волхов' 'Всеволожск' 'Выборг' 'Высоцк'
#  'Гатчина' 'Зеленогорск' 'Ивангород' 'Каменногорск' 'Кингисепп' 'Кириши'
#  'Кировск' 'Колпино' 'Коммунар' 'Красное Село' 'Кронштадт' 'Кудрово'
#  'Лодейное Поле' 'Ломоносов' 'Луга' 'Любань' 'Мурино' 'Никольское'
#  'Новая Ладога' 'Отрадное' 'Павловск' 'Петергоф' 'Пикалёво' 'Подпорожье'
#  'Приморск' 'Приозерск' 'Пушкин' 'Санкт-Петербург' 'Светогорск'
#  'Сертолово' 'Сестрорецк' 'Сланцы' 'Сосновый Бор' 'Сясьстрой' 'Тихвин'
#  'Тосно' 'Шлиссельбург' 'городской поселок Большая Ижора'
#  'городской поселок Янино-1' 'городской посёлок Будогощь'
#  'городской посёлок Виллози' 'городской посёлок Лесогорский'
#  'городской посёлок Мга' 'городской посёлок Назия'
#  'городской посёлок Новоселье' 'городской посёлок Павлово'
#  'городской посёлок Рощино' 'городской посёлок Свирьстрой'
#  'городской посёлок Советский' 'городской посёлок Фёдоровское'
#  'городской посёлок Янино-1' 'деревня Агалатово' 'деревня Аро'
# ...

# %% [markdown]
# Есть такие категории как:
#
# * Города, указанные просто их названиями __оставляю их пока в покое__
# * в ПГТ, городских посёлках и просто посёлках, слова прописаны двумя вариантами - "посёлок" и "поселок", __т.е. "городской посёлок" и "ПГТ" - это одно и тоже, надо переименовать в__ _"поселок городского типа"_ __и убрать__ _"ё"_
# * деревни - __вроде тут всё в порядке__
# * Садовое товарищество и садоводческое некоммерческое товарищество __- это одно и то же, нужно переименовать в__ _"садоводческое некоммерческое товарищество"_
# * Село - __вроде тут всё в порядке__
#
# Разберусь-ка с "ё", разными названиями посёлков (одного типа) и садовыми товариществами (которые тоже одного типа)

# %%
print(data['locality_name'].isnull().sum())
# Out:
# 49

# %%
# сначала разберусь с посёлками и так по-очереди разберусь со всеми моментами, которые мне не нравятся
pd.set_option('display.max_rows', None)

data['locality_name'] = data['locality_name'].str.replace('ё', 'е')
#print(data['locality_name'])
data['locality_name'] = data['locality_name'].str.replace('городской поселок', 'поселок городского типа')
#print(data['locality_name'])
data['locality_name'] = data['locality_name'].str.replace('садовое товарищество', 'садоводческое некоммерческое товарищество')
print(data['locality_name'])
# Out:
# 0                                          Санкт-Петербург
# 1                                           поселок Шушары
# 2                                          Санкт-Петербург
# 3                                          Санкт-Петербург
# 4                                          Санкт-Петербург
# 5                          поселок городского типа Янино-1
# 6                                        поселок Парголово
# 7                                          Санкт-Петербург
# 8                                           поселок Мурино
# 9                                          Санкт-Петербург
# 10                                         Санкт-Петербург
# 11                                               Ломоносов
# 12                                               Сертолово
# 13                                                Петергоф
# 14                                                  Пушкин
# 15                                         Санкт-Петербург
# ...

# %% [markdown]
# Памятуя о том, что у меня всего 49 пропущенных значений в локациях, избавляюсь от них, потому что это незначительная потеря для базы (на мой взгляд)

# %%
data.dropna(subset=['locality_name'], inplace=True)
print(data['locality_name'].isnull().sum()) #ура
# Out:
# 0

# %% [markdown]
# __airports_nearest (расстояние до ближайшего аэропорта в метрах (м))__

# %%
print(data['airports_nearest'].describe())
print(data['airports_nearest'].isnull().sum())
data['airports_nearest'].plot(kind='box')
plt.show()
plt.hist(data['airports_nearest'], color='green', bins=50)
plt.show()
plt.hist(data['airports_nearest'], color='green', bins=30, range=(50000,100000))
plt.show()
# Out:
# count    18116.000000
# mean     28803.225878
# std      12637.314144
# min          0.000000
# 25%      18575.750000
# 50%      26756.500000
# 75%      37294.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64
# 5534

# %% [markdown]
# __city_centers_nearest (расстояние до центра города (м))__

# %%
print(data['city_centers_nearest'].describe())
print(data['city_centers_nearest'].isnull().sum())
data['city_centers_nearest'].plot(kind='box')
plt.show()
plt.hist(data['city_centers_nearest'], color='green', bins=50)
plt.show()
plt.hist(data['city_centers_nearest'], color='green', bins=30, range=(25000, 65000))
plt.show()
# Out:
# count    18139.000000
# mean     14197.860742
# std       8606.830295
# min        181.000000
# 25%       9241.000000
# 50%      13105.000000
# 75%      16293.000000
# max      65968.000000
# Name: city_centers_nearest, dtype: float64
# 5511

# %% [markdown]
# __parks_nearest (парки, находящиеся поблизости от квартиры)__

# %%
print(data['parks_nearest'].isnull().sum())
print()
print(data['parks_nearest'].describe())
print()
data['parks_nearest'].plot(kind='box')
plt.show()
plt.hist(data['parks_nearest'], color='green', bins=30)
plt.show()
plt.hist(data['parks_nearest'], color='green', bins=30, range=(1500, 4000))
plt.show()
# Out:
# 15586
#
# count    8064.000000
# mean      490.830729
# std       342.554386
# min         1.000000
# 25%       288.000000
# 50%       454.500000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %% [markdown]
# __ponds_nearest (водоёмы, находящиеся поблизости от квартиры)__

# %%
print(data['ponds_nearest'].isnull().sum())
print()
print(data['ponds_nearest'].describe())
print()
data['ponds_nearest'].plot(kind='box')
plt.show()
# Out:
# 14565
#
# count    9085.000000
# mean      518.059879
# std       277.841733
# min        13.000000
# 25%       293.000000
# 50%       502.000000
# 75%       730.000000
# max      1344.000000
# Name: ponds_nearest, dtype: float64

# %% [markdown]
# __days_exposition (сколько по времени находится публикация)__

# %%
print(data['days_exposition'].isnull().sum())
data['days_exposition'].plot(kind='box')
plt.show()
# Out:
# 3180

# %% [markdown]
# Проверю-ка как выглядит теперь дата

# %%
print(data.isnull().sum())
print()
colours = ['#00992b', '#d6e3b1'] 
sns.heatmap(data.isnull(), cmap=sns.color_palette(colours))
print() # составляю список недостающих записей для каждого признака
for i in data.columns:
    pct_missing = np.mean(data[i].isnull())
    print('{} - {}%'.format(i, round(pct_missing*100)))
# Out:
# total_images                0
# last_price               2055
# total_area               1237
# first_day_exposition        0
# rooms                     195
# ceiling_height           2965
# floors_total               85
# living_area               128
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area              113
# balcony                     0
# locality_name               0
# airports_nearest         5534
# city_centers_nearest     5511
# parks_around3000            0
# parks_nearest           15586
# ponds_around3000            0
# ponds_nearest           14565
# days_exposition          3180
# dtype: int64
#
#
# total_images - 0%
# last_price - 9%
# total_area - 5%
# first_day_exposition - 0%
# rooms - 1%
# ceiling_height - 13%
# floors_total - 0%
# living_area - 1%
# floor - 0%
# is_apartment - 0%
# studio - 0%
# open_plan - 0%
# kitchen_area - 0%
# balcony - 0%
# ...

# %%
#код ревьюера
data2 = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
(data2['total_area']).hist(bins=30);

# %% [markdown]
# ### **Вывод:**
# <div class="alert alert-info">
#
#
#
# Во время просмотра данных я выявила "проблемные столбцы" с NaN и неправильным типом данных (float, а не int) :
#
# - first_day_exposition,
# - ceiling_height,
# - living_area,
# - is_apartment,
# - kitchen_area,
# - balcony,
# - airports_nearest,
# - cityCenters_nearest (ещё его название изменила на city_centers_nearest, т.е. привела в правильный вид),
# - parks_around3000,
# - parks_nearest,
# - ponds_around3000,
# - ponds_nearest,
# - days_exposition.
#
# Также избавилась от аномалий в:
#
# Значения после 4 комнат очень маленькие, избавляюсь от них.
#
# - ceiling_height и last_price - удалила выбросы методом межквартильного диапазона;
# - total_area - значения после 150 были незначительны
# - rooms - значения после 4 комнат были очень маленькими;
# - airports_nearest - после 70000 шли аномальные значения, значит от них для последующего анализа необходимо избавиться, чтобы сосредоточиться на оставшихся;
# - city_centers_nearest - после 55000 были выбросы;
# - parks_nearest - значения после 2500.
#
# В результате - датасет выглядит "вымытым" и аккуратным.
# </div>

# %% [markdown]
# ## __Посчитайте и добавьте в таблицу новые столбцы__

# %% [markdown]
# _Классифицировать данные необходимо, чтобы было удобнее их анализировать. Новые столбцы в этом как раз помогут_

# %% [markdown]
# #### цену одного квадратного метра "one_meter_price"
#
# * last_price — цена на момент снятия с публикации
# * total_area — общая площадь квартиры в квадратных метрах (м²)
#
# Подумав немного понимаю, что надо разделить цену на общую площадь. Их результат вложу в новый столбик

# %%
data['one_meter_price'] = data['last_price'] / data['total_area']
print(data['one_meter_price'].head(15))
print()
# ура, работает, но так как большинство данных в табличках формата "int", надо изменить его в этот формат
# data['one_meter_price'] = data['one_meter_price'].round() округление тут ненужно - всё выглядет будет коряво
data['one_meter_price'] = np.floor(pd.to_numeric(data['one_meter_price'], errors='coerce')).astype('Int64')
print(data['one_meter_price'].head(15)) # красивое
# Out:
# 0               NaN
# 1      82920.792079
# 2      92785.714286
# 3               NaN
# 4     100000.000000
# 5      95065.789474
# 6      99195.710456
# 7     110544.692737
# 8      87454.764777
# 9      88524.590164
# 10    127525.252525
# 11     75000.000000
# 12     72037.037037
# 13     82943.925234
# 14    122222.222222
# Name: one_meter_price, dtype: float64
#
# 0       <NA>
# 1      82920
# 2      92785
# 3       <NA>
# 4     100000
# 5      95065
# 6      99195
# 7     110544
# 8      87454
# 9      88524
# 10    127525
# 11     75000
# 12     72037
# 13     82943
# 14    122222
# Name: one_meter_price, dtype: Int64

# %% [markdown]
# #### день публикации объявления "weekday"
#
# 0 - понедельник
#
# 1 - вторник
#
# 2 - среда
#
# 3 - четверг
#
# 4 - пятница
#
# 5 - суббота
#
# 6 - воскресенье

# %%
data['weekday'] = data['first_day_exposition'].dt.weekday
print(data['weekday'].head())
# Out:
# 0    3
# 1    1
# 2    3
# 3    4
# 4    1
# Name: weekday, dtype: int64

# %% [markdown]
# #### месяц публикации объявления "month"

# %%
data['month'] = data['first_day_exposition'].dt.month
print(data['month'].head())
# Out:
# 0     3
# 1    12
# 2     8
# 3     7
# 4     6
# Name: month, dtype: int64

# %% [markdown]
# #### год публикации объявления "year"

# %%
data['year'] = data['first_day_exposition'].dt.year
print(data['year'].head())
# Out:
# 0    2019
# 1    2018
# 2    2015
# 3    2015
# 4    2018
# Name: year, dtype: int64

# %% [markdown]
# Даты нормально работают, это хорошо. Разберусь теперь с __типом этажа__ и __расстоянием до центра города__

# %% [markdown]
# #### тип этажа квартиры (значения — «первый», «последний», «другой»), назову по-логике столбик "floor_type"
#
# floor — этаж, значит работаем с этим столбцом.
#
# floors_total — всего этажей в доме. Если немного подумать, то выходит, чтобы указать значения надо использовать столбец _floors_total_
#
# * если этаж равен __1__, то он "первый"
# * если этаж равен __floors_total__, то он "последний"
# * если этаж не равен ни __1__, ни __floors_total__, то он "другой"
#
# раз у меня идея про если, значит использую if-elif
#
# UPD
#
# чтобы использовать функцию, использую _apply_ для категоризации данных по этажам

# %%
def floor_type(row):
    floors_total = row['floors_total']
    floor = row['floor']
    if floor == 1:
        return 'первый'
    elif floor == floors_total:
        return 'последний'
    elif 1 != floor != floors_total:
        return 'другой'
    
data['floor_type'] = data.apply(floor_type, axis=1)

print(data['floor_type'].head(15))
# Out:
# 0        другой
# 1        первый
# 2        другой
# 3        другой
# 4        другой
# 5        другой
# 6        другой
# 7        другой
# 8        другой
# 9        другой
# 10       другой
# 11       другой
# 12    последний
# 13    последний
# 14       первый
# Name: floor_type, dtype: object

# %% [markdown]
# #### расстояние в км до центра города "kilometers_rate"
#
# Выходит, что необходимо перевести метры в километры
#
# В одном километре - 1000 метров, значит надо это как-то указать
#
# _city_centers_nearest_ - всё прописано в метрах
#
# Соответственно, надо количество метров каждого значения _city_centers_nearest_ разделить на 1000, чтобы получились километры для каждой ячейки

# %%
print(data['city_centers_nearest'].head(15))
print()
data['kilometers_rate'] = data['city_centers_nearest'] / 1000
data['kilometers_rate'] = data['kilometers_rate'].fillna(value=0).astype(int)
print(data['kilometers_rate'].head(15))
# Out:
# 0     16028.0
# 1     18603.0
# 2     13933.0
# 3      6800.0
# 4      8098.0
# 5         NaN
# 6     19143.0
# 7     11634.0
# 8         NaN
# 9     15008.0
# 10    13878.0
# 11    51677.0
# 12        NaN
# 13    33058.0
# 14    30759.0
# Name: city_centers_nearest, dtype: float64
#
# 0     16
# 1     18
# 2     13
# 3      6
# 4      8
# 5      0
# 6     19
# 7     11
# 8      0
# 9     15
# 10    13
# 11    51
# 12     0
# 13    33
# 14    30
# Name: kilometers_rate, dtype: int64

# %% [markdown]
# Теперь всё готово к работе

# %% [markdown]
# ### __Вывод:__

# %% [markdown]
# <div class="alert alert-info">
# Было добавлено 6 новых колонок в общую таблицу:
#
# - цена одного квадратного метра "one_meter_price";
#
# - день публикации объявления "weekday";
#
# - месяц публикации объявления "month";
#
# - год публикации объявления "year";
#
# - тип этажа квартиры "floor_type";
#
# - расстояние в км до центра города "kilometers_rate".
# </div>

# %% [markdown]
# ## __Исследовательский анализ данных Ч1__

# %% [markdown]
# __Изучить и описать следующие параметры:__
#
# - общую площадь - используя данные по "total_area";
# - жилую площадь - используя данные по "living_area";
# - площадь кухни - используя данные по "kitchen_area";
# - цену объекта - используя данные по "last_price";
# - количество комнат - используя данные по "rooms";
# - высоту потолков - используя данные по "ceiling_height";
# - этаж квартиры - используя данные по "floor_type";
# - тип этажа квартиры («первый», «последний», «другой») - используя данные по "floor_type";
# - общее количество этажей в доме - используя данные по "floors_total";
# - расстояние до центра города в метрах - используя данные по "city_centers_nearest";
# - расстояние до ближайшего аэропорта - используя данные по "airports_nearest";
# - расстояние до ближайшего парка - используя данные по "parks_nearest";
# - день и месяц публикации объявления - используя данные по "weekday" и "month".
# - Построить гистограммы для каждого параметра

# %% [markdown]
# ### Общую площадь - используя данные по "total_area"

# %% [markdown]
# Необходимо изучить общую площадь, для этого попробую использоывать _plot()_ UPD - получилось не-очень понятно - мне лично ничего не понятно, надо как-то сделать её понятнее
#
# Попробую через _hist_ и использование _plt_
# что мне надо точно знать:
#
# * общая площадь - "Площадь";
# * сколько всего кв.метров - "Квадратные метры";
# * какое количество кваритр - "Количество квартир";
#
# Мне ещё интересно - какие самые большие квартиры по их площади - их стоимость явно будет больше, ну, потому что они самые большие.
# значит, мне надо увидеть хотя бы первые 15ть для примера
# * "Самые большие площади"
# * "Самые маленькие площади"
#
# UPD Ура, получилось понятно и красиво

# %%
plt.hist
plt.hist(data['total_area'], color='green', bins=10, range=(10, 120))
plt.title('Площадь')
plt.xlabel('Квадратные метры')
plt.ylabel('Количество квартир')
plt.show()
print('Самые большие площади:')
print()
print(data['total_area'].sort_values(ascending=False).head())
print()
print('Медиана:', data['total_area'].median())
print()
print('Среднее арифметическое:', data['total_area'].mean().round())
# Out:
# Самые большие площади:
#
# 12831    114.60
# 20809    114.60
# 18273    114.55
# 16094    114.50
# 1966     114.40
# Name: total_area, dtype: float64
#
# Медиана: 50.1
#
# Среднее арифметическое: 54.0

# %% [markdown]
# **Вывод:**
#
# __Большее количество квартир__ - 40 квадратных метров
#
# Самые маленькие площади от 12 кв.м.
#
# Самые большие площади - 114 кв.м.
#
# Медиана составляет 50.1 кв.м.
#
# А среднее значение - 54 кв.м.

# %% [markdown]
# ### Жилую площадь - используя данные по "living_area"

# %% [markdown]
# Что мне надо
# * "Жилая площадь"
# * "Квадратные метры"
# * "Количество квартир"
# * "Самые большие по метражу варианты"
# * "Самые маленькие по метражу варианты"

# %%
plt.hist
plt.hist(data['living_area'], color='green', bins=20, range=(0,70))
plt.title('Жилая площадь')
plt.xlabel('Квадратные метры')
plt.ylabel('Количество квартир')
plt.show()
print('Самые большие по метражу варианты:')
print()
print(data['living_area'].sort_values(ascending=False).head())
print()
print('Медиана:', data['living_area'].median().round())
print()
print('Среднее арифметическое:', data['living_area'].mean().round())
# Out:
# Самые большие по метражу варианты:
#
# 19540    409.7
# 5358     409.0
# 12401    347.5
# 4237     332.0
# 12859    322.3
# Name: living_area, dtype: float64
#
# Медиана: 31.0
#
# Среднее арифметическое: 34.0

# %% [markdown]
# **Вывод:**
#
# Самые большие по метражу квартиры - 409кв.м.
#
# Самые маленькие составляют - 2 кв.м.
#
# Самые распространённые в 20 кв.м.
#
# Далее идёт группа квартир 35 кв.м.
#
# Медиана - 31
#
# Среднее - 34

# %% [markdown]
# ### Площадь кухни - используя данные по "kitchen_area"

# %% [markdown]
# Что мне надо точно знать:
#
# * "Кухни";
# * сама площадь кухонь - "Квадратные метры";
# * "Количество квартир";
# Мне интересно - какие самые большие цифры по комнатам - стоимость квартир явно будет больше из-за их количества. значит, мне надо увидеть хотя бы первые 15ть для примера
#
# * "Самые большие по площади кухни"
# * "Самые маленькие по площади кухни"

# %%
plt.hist(data['kitchen_area'], color='green', bins=10, range=(0, 60))
plt.title('Кухни')
plt.xlabel('Квадратные метры')
plt.ylabel('Количество квартир')
plt.show()
print('Самые большие по площади кухни:')
print()
print(data['kitchen_area'].sort_values(ascending=False).head())
print()
print('Медиана:', data['kitchen_area'].median())
print()
print('Среднее арифметическое:', data['kitchen_area'].mean().round())
# Out:
# Самые большие по площади кухни:
#
# 19540    112.0
# 20215    107.0
# 2489     100.7
# 5358     100.0
# 16239     93.2
# Name: kitchen_area, dtype: float64
#
# Медиана: 10.0
#
# Среднее арифметическое: 11.0

# %% [markdown]
# **Вывод:**
#
# __Самая большая площадь кухонь__ - 112кв.м.
#
# Самое болльшое количество квартир с кухнями размером __6-10кв.м.__
#
# Самая маленькая площадь кухонь - __2кв.м.__
#
# Медиана - 10
#
# Среднее - 11

# %% [markdown]
# ### Цена объекта - используя данные по "last_price"

# %% [markdown]
# Что мне нужно:
# * "Цена квартир"
# * "Стоимость"
# * "Количество квартир"
# * "Самые дорогие варианты"
# * "Самые дешёвые варианты"

# %%
# поделю на 1млн, чтобы данные было удобно просматривать
data['last_price'] = data['last_price'] / 1000000
# print(data['last_price'].head())
plt.hist(data['last_price'], color='green', bins=20, range=(0, 20))
plt.title('Цена квартир')
plt.xlabel('Стоимость')
plt.ylabel('Количество квартир')
plt.show()
print('Самые дорогие варианты:')
print()
print(data['last_price'].sort_values(ascending=False).head())
print()
print('Медиана:', data['last_price'].median())
print()
print('Среднее арифметическое:', data['last_price'].mean().round())
# Out:
# Самые дорогие варианты:
#
# 17738    11.89440
# 13701    11.88000
# 20860    11.87925
# 3165     11.86686
# 21860    11.85800
# Name: last_price, dtype: float64
#
# Медиана: 4.4
#
# Среднее арифметическое: 5.0

# %% [markdown]
# **Вывод:**
#
# Большее количество квартир стоит от 3 до 4 милионов.
#
# Самые дорогие варианты - под 11млн.
#
# Самые дешёвые - 0.01219
#
# Медиана - 4.4, а среднее - 5.

# %% [markdown]
# ### Количество комнат - используя данные по "rooms"

# %% [markdown]
# что мне надо точно знать:
#
# * "Комнаты";
# * сколько всего комнат - "Количество комнат";
# * сколько квартир - "Количество квартир";
#
# Мне интересно - какие самые большие цифры по комнатам - стоимость квартир явно будет больше из-за их количества.
# значит, мне надо увидеть хотя бы первые 15ть для примера
#
# * "Самое большое количество комнат"
# * "Самое маленькое количество комнат"

# %%
plt.hist(data['rooms'], color='green', bins=7, range=(1,7))
plt.title('Комнаты')
plt.xlabel('Количество комнат')
plt.ylabel('Количество квартир')
plt.show()
print('Самое большое количество комнат:')
print()
print(data['rooms'].sort_values(ascending=False).head())
print()
print('Самое маленькое количество комнат:')
print()
print('Медиана:', data['rooms'].median())
print()
print('Среднее арифметическое:', data['rooms'].mean().round())
# Out:
# Самое большое количество комнат:
#
# 15856    5.0
# 16618    5.0
# 9582     5.0
# 8077     5.0
# 14412    5.0
# Name: rooms, dtype: float64
#
# Самое маленькое количество комнат:
#
# Медиана: 2.0
#
# Среднее арифметическое: 2.0

# %% [markdown]
# **Вывод:**
#
# __Самое большое количество квартир__ - с __1__ комнатой, потом немного отстаёт показатель "двушек"
#
# Самое большое количество комнат - 5
#
# Самое маленькое количество комнат - 1
#
# И __Медиана__ и __среднее значение__ показывают -  2 комнаты

# %% [markdown]
# ### Высота потолков - используя данные по "ceiling_height"

# %% [markdown]
# Что мне надо:
#
# * "Высота потолка"
# * "Метры"
# * "Количество квартир"
# * "Самые высокие потолки"

# %%
plt.hist(data.query('(ceiling_height > 2) & (ceiling_height < 4)')['ceiling_height'], color='green', bins=15)
plt.title('Высота потолка')
plt.xlabel('Метры')
plt.ylabel('Количество квартир')
plt.show()
print('Самые высокие потолки:')
print()
print(data['ceiling_height'].sort_values(ascending=False).head())
print()
print('Медиана:', data['ceiling_height'].median())
print()
print('Среднее арифметическое:', data['ceiling_height'].mean().round())
# Out:
# Самые высокие потолки:
#
# 5405     2.85
# 17169    2.85
# 8399     2.85
# 20212    2.85
# 12837    2.85
# Name: ceiling_height, dtype: float64
#
# Медиана: 2.65
#
# Среднее арифметическое: 3.0

# %% [markdown]
# **Вывод:**
#
# Самыми большими значениями получились 2.65, т.е. можно сделать вывод, что они совпадают с медианным значением в 2.65.
#
# Самые высокие потолки имеют значение в 2.85, а самые маленькие по высоте - 2.45
#
# Медиана - 2.65
#
# Средняя высота  3 метра

# %% [markdown]
# ### Этаж квартиры - используя данные по "floor"

# %% [markdown]
# Что мне надо
# * "Этаж"
# * "Количество этажей"
# * "Количество квартир"
# * "Самое большое количество этажей"

# %%
plt.hist(data['floor'], color='green', bins=15, range=(0,30))
plt.title('Этаж')
plt.xlabel('Тип этажей')
plt.ylabel('Количество квартир')
plt.show()
print('Самое большое количество типов:')
print()
print(data['floor'].sort_values(ascending=False).head())
print()
print(data['floor'].sort_values(ascending=False).tail())
print()
print('Медиана:', data['ceiling_height'].median())
print()
print('Среднее арифметическое:', data['ceiling_height'].mean().round())
# Out:
# Самое большое количество типов:
#
# 18218    33
# 11575    32
# 18629    31
# 1917     30
# 11079    29
# Name: floor, dtype: int64
#
# 16209    1
# 2620     1
# 2624     1
# 16200    1
# 23698    1
# Name: floor, dtype: int64
#
# Медиана: 2.65
#
# Среднее арифметическое: 3.0

# %% [markdown]
# **Вывод:**
#
# Самое большое значение количества типов этажей - __33__, самое маленькое - __1__
#
# Больше всего квартир на __4 и 5__ этажах
#
# Медиана - 2.65, а среднее 3.

# %% [markdown]
# ### Тип этажа квартиры («первый», «последний», «другой») - используя данные по "floor_type"

# %% [markdown]
# Что мне надо:
#
# * "Этажи"
# * "Номер этажа"
# * "Количество квартир"
# * "Квартиры на самых высоких этажах"

# %%
plt.hist(data['floor_type'], color='green', bins=5)
plt.title('Этажи')
plt.xlabel('Название этажа')
plt.ylabel('Количество квартир')
plt.show()
print('Квартиры на самых высоких этажах:')
print()
print(data['floor_type'].sort_values(ascending=False).head())
print()
print(data['floor_type'].sort_values(ascending=False).tail())
# Out:
# Квартиры на самых высоких этажах:
#
# 9461     последний
# 21886    последний
# 16491    последний
# 16494    последний
# 2454     последний
# Name: floor_type, dtype: object
#
# 9065     другой
# 9064     другой
# 9060     другой
# 9057     другой
# 11844    другой
# Name: floor_type, dtype: object

# %% [markdown]
# **Вывод:**
#
# __Самое большое количество квартир__ _между 1м и последним этажами_,
#
# Следом идут __Последний этаж__ и __Первый этаж__

# %% [markdown]
# ### Общее количество этажей в доме - используя данные по "floors_total"

# %% [markdown]
# Что мне надо:
#
# * "Общее по этажам"
# * "Количество этажей"
# * "Количество квартир"
# * "Самое большое количество этажей"

# %%
plt.hist(data['floors_total'], color='green', bins=25, range=(0,30))
plt.title('Общее по этажам')
plt.xlabel('Количество этажей')
plt.ylabel('Количество квартир')
plt.show()
print('Самое большое количество этажей:')
print()
print(data['floors_total'].sort_values(ascending=False).head())
print()
print('Медиана:', data['ceiling_height'].median())
print()
print('Среднее арифметическое:', data['ceiling_height'].mean().round())
# Out:
# Самое большое количество этажей:
#
# 2253     60.0
# 16731    52.0
# 16934    37.0
# 5807     36.0
# 11079    36.0
# Name: floors_total, dtype: float64
#
# Медиана: 2.65
#
# Среднее арифметическое: 3.0

# %% [markdown]
# **Вывод:**
#
# Самое большое значение количества этажей __60__, самое маленькое - __1__
#
# Больше всего квартир на __5 и 9__ этажах.
#
# Медиана __2.65__, а среднее - __3__

# %% [markdown]
# ### Расстояние до центра города в метрах - используя данные по "city_centers_nearest"

# %% [markdown]
# Что мне нужно:
#
# * "Расстояние до центра"
# * "Метры"
# * "Количество квартир"
# * "Самое большое расстояние"

# %%
plt.hist(data['city_centers_nearest'], color='green', bins=25)
plt.title('Расстояние до центра')
plt.xlabel('Метры')
plt.ylabel('Количество квартир')
plt.show()
print('Самое большое расстояние в метрах:')
print()
print(data['city_centers_nearest'].sort_values(ascending=False).head())
print()
print('Медиана:', data['city_centers_nearest'].median())
print()
print('Среднее арифметическое:', data['city_centers_nearest'].mean().round())
# Out:
# Самое большое расстояние в метрах:
#
# 9640     65968.0
# 5340     65952.0
# 577      65764.0
# 20746    65105.0
# 5218     64857.0
# Name: city_centers_nearest, dtype: float64
#
# Медиана: 13105.0
#
# Среднее арифметическое: 14198.0

# %% [markdown]
# **Вывод:**
#
# Самое большое расстояние до центра города составляет 65968 метров, а самое маленькое - почти 500м.
#
# Больше всего квартир находится на расстоянии __от приблизительно 11 до  15 километров__.
#
# Медиана - 13105 метра
#
# Среднее - 14198 метров

# %% [markdown]
# ### Расстояние до ближайшего аэропорта - используя данные по "airports_nearest"

# %% [markdown]
# Что мне нужно:
#
# * "Расстояние до аэропорта"
# * "Метры"
# * "Количество квартир"
# * "Самое большое расстояние"

# %%
plt.hist(data['airports_nearest'], color='green', bins=35, range=(1, 70000))
plt.title('Расстояние до аэропорта')
plt.xlabel('Метры')
plt.ylabel('Количество квартир')
plt.show()
print('Самое большое расстояние в метрах:')
print()
print(data['airports_nearest'].sort_values(ascending=False).head())
print()
print('Медиана:', data['airports_nearest'].median())
print()
print('Среднее арифметическое:', data['airports_nearest'].mean().round())
# Out:
# Самое большое расстояние в метрах:
#
# 9640     84869.0
# 5340     84853.0
# 577      84665.0
# 20746    84006.0
# 5218     83758.0
# Name: airports_nearest, dtype: float64
#
# Медиана: 26756.5
#
# Среднее арифметическое: 28803.0

# %% [markdown]
# **Вывод:**
#
# Самое большое расстояние до аэропорта составляет 84869, а самое маленькое -  около 6914 метров.
#
# Больше всего квартир находится на расстоянии __около 18 километров__.
#
# Медиана - 26756.5 метра
#
# Среднее - 28803 метра

# %% [markdown]
# ### Расстояние до ближайшего парка - используя данные по "parks_nearest"

# %% [markdown]
# Что мне нужно:
#
# * "Расстояние до парка"
# * "Метры"
# * "Количество квартир"
# * "Самое большое расстояние"

# %%
plt.hist(data['parks_nearest'], color='green', bins=15)
plt.title('Расстояние до парка')
plt.xlabel('Метры')
plt.ylabel('Количество квартир')
plt.show()
print('Самое большое расстояние в метрах:')
print()
print(data['parks_nearest'].sort_values(ascending=False).head())
print()
print('Медиана:', data['parks_nearest'].median())
print()
print('Среднее арифметическое:', data['parks_nearest'].mean().round())
# Out:
# Самое большое расстояние в метрах:
#
# 10959    3190.0
# 19430    3190.0
# 1590     3064.0
# 19208    3013.0
# 23080    2984.0
# Name: parks_nearest, dtype: float64
#
# Медиана: 454.5
#
# Среднее арифметическое: 491.0

# %% [markdown]
# **Вывод:**
#
# Самое большое расстояние до парка - 3190, а самое маленькое - до 1500м.
#
# Самое большое количество квартир находится на расстоянии около 350 метров от ближайшего парка.
#
# Медиана - 454.5
#
# Среднее - 491

# %% [markdown]
# ### День и месяц публикации объявления - используя данные по "weekday" и "month"

# %% [markdown]
# Необходимо узнать по месяц и день недели, когда была сделана публикация
# Сделаю зелёным - день недели, морским зелёным - месяц
# * "День и месяц публикации"
# * "День и месяц"
# * "Количество квартир"
# * "Самое большое количество квартир"
# * "Самое маленькое количество квартир"

# %%
plt.hist(data['weekday'], color='green', bins=7)
plt.title('День публикации')
plt.xlabel('День')
plt.ylabel('Количество квартир')
plt.show()
print()
print('Самое большое количество квартир по дням:')
print(data['weekday'].sort_values(ascending=False).head())
print()
print('Самое маленькое количество квартир по дням:')
print(data['weekday'].sort_values(ascending=False).tail())
print()
print('Медиана:', data['weekday'].median())
print('Среднее арифметическое:', data['weekday'].mean().round())
print()
plt.hist(data['month'], color='mediumseagreen', bins=12)
plt.title('Месяц публикации')
plt.xlabel('Месяц')
plt.ylabel('Количество квартир')
plt.show()
print()
print('Самое большое количество квартир по месяцам:')
print(data['month'].sort_values(ascending=False).head())
print()
print('Самое маленькое количество квартир по месяцам:')
print(data['month'].sort_values(ascending=False).tail())
print()
print('Медиана:', data['month'].median())
print('Среднее арифметическое:', data['month'].mean().round())
# Out:
# Самое большое количество квартир по дням:
# 19552    6
# 8137     6
# 7322     6
# 8923     6
# 8924     6
# Name: weekday, dtype: int64
#
# Самое маленькое количество квартир по дням:
# 14673    0
# 6639     0
# 20178    0
# 20179    0
# 10033    0
# Name: weekday, dtype: int64
#
# Медиана: 3.0
# Среднее арифметическое: 3.0
# Самое большое количество квартир по месяцам:
# 10802    12
# 15919    12
# 6578     12
# 1843     12
# 6573     12
# Name: month, dtype: int64
#
# Самое маленькое количество квартир по месяцам:
# 16526    1
# 6093     1
# 997      1
# 20320    1
# 14542    1
# Name: month, dtype: int64
#
# Медиана: 6.0
# Среднее арифметическое: 6.0

# %% [markdown]
# **Вывод:**
#
# Помню о том, что дни недели считаем как - __0, 1, 2, 3, 4, 5, 6__, а месяцев у нас __12__.
#
# __Дни недели__
#
# Во четверг и вторник зарегестрировали больше всего квартир, с чуть меньшим количеством идут регистрации по пятницам и средам , на третьем месте идут понедельники.
#
# Медиана: 3
# Среднее арифметическое: 3
#
# - _Можно сделать вывод_, что в течение середины недели происходит самое большое количество публикаций. В конце недели - субботу и воскресенье - наборот, меньше публикаций. Скорее всего, это связано с тем, что в начале недели люди испытывают меньшее напряжение и готовы к новым начинаниям.
#
# __Месяцы__
#
# Самые "популярные" для публикаций месяцы - Февраль и, с незначительным остставанием, Март. Серебро у Апреля, а бронза у Ноября. Самое маленькое количество публикаций получается в Мае.
#
# Медиана: 6.0
# Среднее арифметическое: 6.0
#
# - _Можно сделать вывод_, что чаще квартиры регистрируют в начале года и под его конец. Скорее всего, это связано с тем, что в начале года - нам всем хочется изменить свою жизнь, а под конец - успеть сделать запланированное))
#
# __Медиана и среднее совпадаю и в общем - это среда и июнь__

# %% [markdown]
# ## __Исследовательский анализ данных Ч2__

# %% [markdown]
# ### Изучить, как быстро продавались квартиры (столбец days_exposition).Сколько дней «висело» каждое объявление.

# %% [markdown]
# Что мне надо:
#
# * "Время продажи"
# * "Дни" - сколько дней было выложено объявление
# * "Количество квартир"
# * "Самое долгое время публикаций"
# * "Самое короткое время публикаций"

# %%
plt.hist(data['days_exposition'], color='green', bins=20, range=(0, 1800))
plt.title('Время продажи')
plt.xlabel('Дни')
plt.ylabel('Количество квартир')
plt.show()
plt.hist(data['days_exposition'], color='green', bins=20, range=(1000, 1800))
plt.title('Время продажи')
plt.xlabel('Дни')
plt.ylabel('Количество квартир')
plt.show()

# %% [markdown]
# Самое долгое время публикаций - __до 1600 дней.__ - а сколько по-времени вообще можно держать публикацию?
#
# Самым быстрым сроком продажи кваритр можно считать от __нескольких дней до 50 (чуть больше полутора месяцев)__
#
# Самым долгим сроком продажи квартир можно считать от __200 (почти полгода) и до почти 1500 дней (примерно 4 года)__
#
# Самое большое количество квартир продаётся от __1 до 200__ дней
#
# Загуглила - что вообще по срокам в Яндекс-недвижимости в Справке (https://yandex.ru/support/realty/owner/home/add-ads-housing.html)
#
# Ого!
#
# ![image.png](attachment:image.png)
#
# По этим данным понятно, что значения выше 90 дней - какие-то аномалии
#
# Посмотрю в без нулей.
#
# По диаграмме размаха будет немного яснее, что происходит

# %%
plt.hist(data['days_exposition'], color='green', bins=100, range=(0, 200))
plt.title('Время продажи')
plt.xlabel('Дни')
plt.ylabel('Количество квартир')
plt.show()
print('Самое долгое время публикаций:')
print()
print(data[data['days_exposition']!=0]['days_exposition'].sort_values(ascending=False).head())
print()
print('Самое короткое время публикаций:')
print(data[data['days_exposition']!=0]['days_exposition'].sort_values(ascending=True).head())
print()
print('Медиана:', data[data['days_exposition']!=0]['days_exposition'].median())
print()
print('Среднее арифметическое:', data[data['days_exposition']!=0]['days_exposition'].mean().round())
print()
print(data[data['days_exposition']!=0]['days_exposition'].describe())
#print(data[data['days_exposition']!=0]['days_exposition'].value_counts())
# Out:
# Самое долгое время публикаций:
#
# 18843    1580.0
# 1109     1572.0
# 9553     1553.0
# 1885     1513.0
# 6691     1512.0
# Name: days_exposition, dtype: float64
#
# Самое короткое время публикаций:
# 1632     1.0
# 16212    2.0
# 13061    2.0
# 16053    2.0
# 23116    3.0
# Name: days_exposition, dtype: float64
#
# Медиана: 95.0
#
# Среднее арифметическое: 181.0
#
# count    20470.000000
# mean       180.753200
# std        219.777916
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Медиана: 95.0
#
# Среднее арифметическое: 181.0
#
# Отобразив больше корзин и меньше сделав размах, стали заметны аномалии с такими значениями - 45, 60 и 90 дней - чаще всего снимают заявления, почему? Вспоминаю заяндексенные __сроки публикации__. Логично добавить в этот список числа 7 и 30. Эти значения убирать не надо, так как это не выбросы, а особенность функционирования системы размещения (мне ревьюер так сказал Ж)). Поэтому их нельзя убирать, чтобы просмотреть данные без потерь.

# %%
plt.hist(data['days_exposition'], color='green', bins=20, range=(0, 1000))
plt.title('Время продажи')
plt.xlabel('Дни')
plt.ylabel('Количество квартир')
plt.show()
print()
plt.hist(data['days_exposition'], color='green', bins=50, range=(0, 200))
plt.title('Время продажи')
plt.xlabel('Дни')
plt.ylabel('Количество квартир')
plt.show()
print('Медиана:', data['days_exposition'].median())
print()
print('Среднее арифметическое:', data['days_exposition'].mean().round())
print()
# Out:
# Медиана: 95.0
#
# Среднее арифметическое: 181.0

# %% [markdown]
# **Вывод:**
#
# Самое большое количество квартир продаётся от __1 до 100__ дней
#
# Самое короткое время публикаций - 1 день.
#
# Большая часть квартир продаётся в эти временные рамки - 45 и 60 дней, также можно отметить, что большинство квартир продаётся именно в период до 100 дней.
#
# Медиана: 95
#
# Среднее арифметическое: 181.0

# %% [markdown]
# ### Также, мне стало интересно - а влияет ли количество фотографий на продажу квартир (_total_images_ ).

# %% [markdown]
# Что мне надо:
#
# total_images — число фотографий квартиры в объявлении
#
# days_exposition — сколько дней было размещено объявление (от публикации до снятия)
#
# * "Количество фотографий"
# * "Фотографии" - сколько фотографий было выложено и сколько дней оно было активно
# * "Количество квартир"
# * "Самое большое количество дней к количеству фотографий"
# * "Самое большое количество фотографий к количеству дней"

# %%
plt.hist(data['total_images'], color='green', bins=30, range=(1, 35))
plt.title('Количество фотографий')
plt.xlabel('Фотографии')
plt.ylabel('Количество квартир')
plt.show()
print('Самое большое количество дней - days_exposition к количествоу фотографий - total_images:')
print()
print(data[['days_exposition', 'total_images']].sort_values(by='days_exposition',  ascending=False).head())
print()
print('Самое большое количество фотографий - total_images к количеству дней - days_exposition:')
print(data[['total_images', 'days_exposition']].sort_values(by='total_images', ascending=False).head())
print()
print('Медиана:', data['total_images'].median())
print()
print('Среднее арифметическое:', data['total_images'].mean().round())
# Out:
# Самое большое количество дней - days_exposition к количествоу фотографий - total_images:
#
#        days_exposition  total_images
# 18843           1580.0            11
# 1109            1572.0             1
# 9553            1553.0            11
# 1885            1513.0             2
# 6691            1512.0             3
#
# Самое большое количество фотографий - total_images к количеству дней - days_exposition:
#        total_images  days_exposition
# 12667            50              5.0
# 17396            50            106.0
# 9778             50              3.0
# 15157            42            172.0
# 1058             39            106.0
#
# Медиана: 9.0
#
# Среднее арифметическое: 10.0

# %% [markdown]
# **Вывод:**
#
# Смотря на самое долгое время публикаций (1580 дней) и количество фотографий (количество колеблется от 1 до 11), можно сделать вывод - что фотографий не так уж много и, скорее всего, это влияет на покупателей - ведь "лицо" квартиры важно увидеть (в каком она состоянии, каков ремонт и прочие аспекты).
#
# Смотрю на самое большое количество фотографий (39), дни публикации тоже колеблются - минимальное количество дней - 47, а максимальное - 334.
#
# Медиана -  9, а Среднее - 10 фотографий и тут они сопадают с графиком - больше всего квартир с 9-10 фотографиями.
#
# Можно сделать неочевидный вывод, что количество фотографий влияет на покупку квартиры.

# %% [markdown]
# ### Какие факторы больше всего влияют на общую (полную) стоимость объекта?
#
# Нужно построить графики, которые покажут зависимость цены от указанных ниже параметров:
#
# - общей площади;
# - жилой площади;
# - площади кухни;
# - количество комнат;
# - типа этажа, на котором расположена квартира (первый, последний, другой);
# - даты размещения (день недели, месяц, год).
#
# Мне нужно расчитать зависимость цены от вышеописанных факторов. Делаю по-порядку, чтобы не запутаться.

# %% [markdown]
# #### общей площади total_area

# %% [markdown]
# __Скорее всего надо использовать _pivot_table_ и посмотреть какова корреляция (хорошо, что где-то я её видела во время уроков, а то ломала голову как посчитать взаимоотношение площади и стоимости))))__

# %%
data.pivot_table(index='total_area',
                 values='last_price',
                aggfunc=['median']).plot(y='median', style='o')
plt.title('Цена общей площади')
plt.xlabel('Площадь')
plt.ylabel('Цена')
plt.show()
print('Корреляция Пирсона по цене и общей площади составляет:', (data['total_area'].corr(data['last_price'])))
# Out:
# Корреляция Пирсона по цене и общей площади составляет: 0.6938396292817772

# %% [markdown]
# __UPD__ - изменила немного вид и теперь выглядит красиво.
#
# **Вывод:**
#
# last_price - цена на момент продажи квартиры
#
# Можно сделать вывод, что цена квартиры на прямую зависит от общей площади.
#
# Корреляция Пирсона по цене и общей площади составляет: 0.69

# %% [markdown]
# #### жилой площади living_area

# %%
data.pivot_table(index='living_area',
                 values='last_price',
                aggfunc=['median']).plot(y='median', style='o')
plt.title('Цена жилой площади')
plt.xlabel('Площадь')
plt.ylabel('Цена')
plt.show()
print('Корреляция Пирсона по цене и жилой площади составляет:', (data['living_area'].corr(data['last_price'])))
# Out:
# Корреляция Пирсона по цене и жилой площади составляет: 0.5493191047125064

# %% [markdown]
# **Вывод:**
#
# Тут корреляция Пирсона по цене и жилой площади - 0.54. Основная масса жилой площади находится от 15 до 50 по площади и от 3 до 8 по медиане.
#
# Стоимость квартир возрастает в зависимости от метража. Это факт.

# %% [markdown]
# #### от площади кухни kitchen_area

# %%
data.pivot_table(index='kitchen_area',
                 values='last_price',
                aggfunc=['median']).plot(y='median', style='o')
plt.title('Цена кухонь')
plt.xlabel('Площадь')
plt.ylabel('Цена')
plt.show()
print('Корреляция Пирсона по цене и площади кухонь составляет:', (data['kitchen_area'].corr(data['last_price'])))
# Out:
# Корреляция Пирсона по цене и площади кухонь составляет: 0.44858335251582804

# %% [markdown]
# **Вывод:**
#
# Основная масса кухонь находится от 5 до 15 по площади и от 3 до 6 по медиане.
#
# Стоимость квартир возрастает в зависимости от метража кухни. Это факт, но не такой знаячащий как цена жилой площади.
#
# Корреляция Пирсона по цене и площади кухонь составляет - 0.44

# %% [markdown]
# #### от числа комнат rooms

# %%
pivot_table_price_rooms = data.pivot_table(index='rooms',
                                              values='last_price',
                                              aggfunc=['mean', 'count', 'median'])
pivot_table_price_rooms.columns = ['mean', 'count', 'median']
pivot_table_price_rooms.query('rooms > 0').plot(y='median')
pivot_table_price_rooms.query('rooms > 0').sort_values('median', ascending=False)
print('Корреляция Пирсона по цене и числу комнат составляет:', (data['rooms'].corr(data['last_price'])))
# Out:
# Корреляция Пирсона по цене и числу комнат составляет: 0.4489269807476606

# %% [markdown]
# **Вывод:**
#
# Корреляция Пирсона по цене и числу комнат составляет: 0.44
#
# Также можно отметить, что после 4 комнат, цена квартир значительно повышается.
#
# Цена квартир зависит напрямую от количества комнат. Т.е. количество комнат влияет на стоимость квартиры.

# %% [markdown]
# #### типа этажа floor_type

# %%
pivot_table_price_floor = data.pivot_table(index='floor_type',
                                              values='last_price',
                                              aggfunc=['mean', 'count', 'median'])
pivot_table_price_floor.columns = ['mean', 'count', 'median']
pivot_table_price_floor.plot(y='median');

# %% [markdown]
# **Вывод:**
#
# Чем ближе к первому этажу находится квартира, тем ниже её стоимость. Самые дешёвые кавртиры - на пером этаже. Цена квартир на последних этажах ниже, чем на других (кроме первого).

# %% [markdown]
# #### даты размещения weekday, month, year

# %%
print('Взаимоотношение цены и дня недели')
pivot_table_price_weekday_exposition = data.pivot_table(index='weekday',
                                              values='last_price',
                                              aggfunc=['mean', 'count', 'median'])
pivot_table_price_weekday_exposition.columns = ['mean', 'count', 'median']
pivot_table_price_weekday_exposition.plot(y='median')
# Тут корреляция = -0.004552826116740451 и ничего непонятно - как так оно в минус уходит, попробую через wort_values
# print('Корреляция Пирсона по цене и дате публикации составляет:', data['weekday'].corr(data['one_meter_price']))
print(pivot_table_price_weekday_exposition.sort_values('median', ascending=False))
print()
print('Взаимоотношение цены и месяца')
pivot_table_price_month_exposition = data.pivot_table(index='month',
                                              values='last_price',
                                              aggfunc=['mean', 'count', 'median'])
pivot_table_price_month_exposition.columns = ['mean', 'count', 'median']
pivot_table_price_month_exposition.plot(y='median')
print(pivot_table_price_month_exposition.sort_values('median', ascending=False))
print()
print('Взаимоотношение цены и года')
pivot_table_price_year_exposition = data.pivot_table(index='year',
                                              values='last_price',
                                              aggfunc=['mean', 'count', 'median'])
pivot_table_price_year_exposition.columns = ['mean', 'count', 'median']
pivot_table_price_year_exposition.plot(y='median')
print(pivot_table_price_year_exposition.sort_values('median', ascending=False))
# Out:
# Взаимоотношение цены и дня недели
#              mean  count  median
# weekday
# 1        4.898055   3823   4.499
# 2        4.867238   3604   4.490
# 0        4.834044   3288   4.400
# 3        4.848652   3862   4.400
# 5        4.735849   1781   4.400
# 6        4.777934   1563   4.390
# 4        4.819782   3674   4.350
#
# Взаимоотношение цены и месяца
#            mean  count    median
# month
# 4      4.945205   2173  4.574160
# 12     4.854752   1494  4.480000
# 11     4.866506   2150  4.455000
# 3      4.804278   2362  4.429242
# 9      4.949787   1800  4.401770
# 1      4.794160   1349  4.400000
# 2      4.833719   2413  4.400000
# 10     4.805190   1952  4.397500
# 8      4.838271   1594  4.380000
# 5      4.824609   1159  4.350000
# 7      4.834934   1536  4.350000
# 6      4.672359   1613  4.200000
#
# Взаимоотношение цены и года
#           mean  count  median
# year
# 2014  5.782435     89   5.500
# 2015  5.244956   1000   4.895
# 2019  5.100008   2611   4.800
# ...

# %% [markdown]
# **Вывод:**
#
# __День недели__
#
# С понедельника по вторник стоимость квартир падает. к середине недели она возрастае (со вторника по среду). Начиная со среды, цена резко падает и на низком уровне находится до конца недели.
#
# __Месяц__
#
# Самое низкое значение по цене квартир можно отметить в июне.
#
# Самое высокое значение по цене квартир можно зафиксировать в апреле.
#
# Цена квартир постепенно растёт к апрелю и резко падает до июня. После июня, она постепенно растёт до ноября и виден спад цены в декабре.
#
# __Год__
#
# С 2014 года по 16й был спад цен на квартиры - оно и не удивительно, ведь кризис был.
#
# Тенденция дешёвых квартир продолжалась с 2016 до 2017 (потому что экономика ещё не вышла из кризиса).
#
# С 2017 года по 2019 цены начали значительно расти (это тоже понятно - экономика улучшается, логично предположить, что и зп), но не смогли пробить "потолок" 2014 года.

# %% [markdown]
# ### Посчитать среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений.

# %% [markdown]
# Выделить населённые пункты с самой высокой и низкой стоимостью квадратного метра.
# Эти данные можно найти по имени в столбце _locality_name_.

# %%
pivot_table_price_meter_locality = data.pivot_table(index='locality_name',
                                                             values='one_meter_price',
                                                             aggfunc=['count', 'mean', 'median'])
pivot_table_price_meter_locality.columns = ['count', 'mean', 'median']
pivot_table_price_meter_locality = pivot_table_price_meter_locality.sort_values('count', ascending=False).head(10)
print(pivot_table_price_meter_locality)
print()
print('Самая высокая стоимость в')
print(pivot_table_price_meter_locality[pivot_table_price_meter_locality['mean'] == pivot_table_price_meter_locality['mean'].max()])
print()
print('Самая низкая стоимость в')
print(pivot_table_price_meter_locality[pivot_table_price_meter_locality['mean'] == pivot_table_price_meter_locality['mean'].min()])
# Out:
#                    count           mean    median
# locality_name
# Санкт-Петербург    13607  105684.203278  102061.0
# поселок Мурино       556   85681.305755   85878.0
# поселок Шушары       437   78704.434783   76829.0
# Всеволожск           394   67221.964467   65789.0
# Пушкин               336  100461.619048   98454.0
# Колпино              335   75221.444776   74722.0
# поселок Парголово    326   90331.840491   91779.5
# Гатчина              303   68663.584158   67796.0
# деревня Кудрово      298   92409.265101   91831.5
# Выборг               228   58225.201754   58232.5
#
# Самая высокая стоимость в
#                  count           mean    median
# locality_name
# Санкт-Петербург  13607  105684.203278  102061.0
#
# Самая низкая стоимость в
#                count          mean   median
# locality_name
# Выборг           228  58225.201754  58232.5

# %% [markdown]
# **Вывод:**
#
# Из 10 представленных в выборке, самая высокая стоимость жилья в __Санкт-Петербурге__, а самая низка в __Выборге__.
#
# Можно сделать вывод, что чем ближе к Санкт-Петербургу находится поселение - тем выше цена квартир.

# %% [markdown]
# ### Ранее было посчитано расстояние до центра в километрах.
#
# Теперь надо выделить квартиры в Санкт-Петербурге (там самые дорогие квартиры) с помощью столбца locality_name и вычислить среднюю цену каждого километра.
#
# Насколько я понимаю, в каждой квартире есть километровое обозначение - расстояние до центра, значит нужно вспомнить про многострадальный (_потому что я с ним долго "возилась" Ж)_) city_centers_nearest. Также нужно выбрать именно Петербург, чтобы не смотреть данные по всем городам.
# Наверное мне тут поможет полюбившийся pivot_table.
#
# Как же стоимость объектов зависит от их расстояния до центра города?

# %%
SPB_filtered = data.query('locality_name == "Санкт-Петербург"').pivot_table(index='kilometers_rate', values='last_price').plot(grid=True, style='o-', xlim=(0,15), figsize=(10, 5))
plt.show()

# %% [markdown]
# **Вывод:**
#
# До отметки в 3 километра, цена колеблется, но всё-таки понижается. После отметки в 3км, цена неотступно понижается.
#
# Чем дальше от центра, тем дешевле стоимость жилья.

# %% [markdown]
# ## __Общий вывод__

# %% [markdown]
# ________________________<b>Сроки продажи квартир.</b>________________________
#
# ![image-46.png](attachment:image-46.png)
#
# Самое большое количество квартир продаётся от 1 до 100(чуть больше 3 месяцев) дней
#
# Самое короткое время публикаций - 1 день.
#
# Большая часть квартир продаётся в эти временные рамки - 45(почти полтора месяца) и 60(почти два месяца) дней, также можно отметить, что большинство квартир продаётся именно в период до 100 дней.
#
# Медиана: 95
#
# Среднее арифметическое: 181.0
#
# ________________________<b>Фотографии квартир.</b>________________________
#
# ![image-41.png](attachment:image-41.png)
#
# Я обнаружила очень интересный фактор, который можно было бы впоследствии изучить более детально. Пока что получились такие результаты - количество фотографий влияет на покупку квартиры.
#
# Смотря на самое долгое время публикаций (1512 дней и последующие 14 - они колеблются до 1151) и количество фотографий (количество колеблется от 1 до 15), можно сделать вывод - что фотографий не так уж много и, скорее всего, это влияет на покупателей - ведь "лицо" квартиры важно увидеть (в каком она состоянии, каков ремонт и прочие аспекты).
#
# Смотрю на самое большое количество фотографий (32 штуки) и последующие 14 (цифра колеблется, но минимальное значение - 20), дни публикации тоже колеблются - минимальное количество дней - 5, а максимальное - 334.
#
# Медиана - 9, а Среднее - 10 фотографий и тут они сопадают с графиком - больше всего квартир с 9-10 фотографиями.
#
# Можно сделать неочевидный вывод, что количество фотографий влияет на покупку квартиры.
#
# ________________________<b>Влияние определённых факторов на полную стоимость объекта.</b>________________________
#
# * цена общей площади
# ![image-42.png](attachment:image-42.png)
# Смотря на график, можно сделать вывод, что цена квартиры на прямую зависит от общей площади. Заметно, что большинство квартир "сгрудились" в разбросе до медианы от 4 до 6 и площадью от 30 до 70. Значения в графике постепенно возрастают, что приводит к выводу - чем выше общая площадь, тем выше цена за квартиру;
#
# * цена жилой площади
# ![image-43.png](attachment:image-43.png)
#  Основная масса жилой площади находится от 15 до 50 по площади и от 3 до 8 по медиане. Основная масса жилой площади находится от 15 до 50 по площади и от 3,5 до 6 по медиане. Стоимость квартир возрастает в зависимости от метража. Это факт;
#
# * цена по кухням
# ![image-44.png](attachment:image-44.png)
# Основная масса кухонь находится от 5 до 15 по площади и от 3 до 6 по медиане. Стоимость квартир возрастает в зависимости от метража кухни. Это факт, но не такой значащий как цена жилой площади;
#
# * количество комнат
# ![image-45.png](attachment:image-45.png)
# Также можно отметить, что после 4 комнат, цена квартир значительно повышается. На графике заметно, что цена повышается прямо пропорционально количеству комнат. Из этого выходит, что цена квартир зависит напрямую от количества комнат;
#
#
# <b>Выходит, что больше всего влияют цена за общую площадь квартиры и цена за жилую площадь. Меньшее и равносильное влияние на цену имеют результаты по кухням и количеству комнат. </b>
#
# __Этаж влияет на цену__
#
# ![image-47.png](attachment:image-47.png)
#
# Чем ближе к первому этажу находится квартира, тем ниже её стоимость. Самые дешёвые кавртиры - на пером этаже. Цена квартир на последних этажах ниже, чем на других (кроме первого).
#
# __Даты тоже влияют на цену__
#
# * __День недели.__
# ![image-48.png](attachment:image-48.png)
#
# С понедельника по вторник стоимость квартир падает. к середине недели она возрастае (со вторника по среду). Начиная со среды, цена резко падает и на низком уровне находится до конца недели.
#
# * __Месяц.__
# ![image-49.png](attachment:image-49.png)
#
# Самое низкое значение по цене квартир можно отметить в июне. Самое высокое значение по цене квартир можно зафиксировать в апреле. Цена квартир постепенно растёт к апрелю и резко падает до июня. После июня, она постепенно растёт до ноября и виден спад цены в декабре.
#
# * __Год.__
# ![image-50.png](attachment:image-50.png)
#
# С 2014 года по 16й был спад цен на квартиры - оно и не удивительно, ведь кризис был. Тенденция дешёвых квартир продолжалась с 2016 до 2017 (потому что экономика ещё не вышла из кризиса). С 2017 года по 2019 цены начали значительно расти (это тоже понятно - экономика улучшается, логично предположить, что и зп), но не смогли пробить "потолок" 2014 года.
#
# ________________________<b>В топе из 10 населённых пунктов получилась такая статистика.</b>________________________
#
# ![image-51.png](attachment:image-51.png)
#
# Из 10 представленных в выборке, самая высокая стоимость жилья в Санкт-Петербурге(средне арифметическое - 104169.0, медиана - 100000.0), а самая низкая в Красном Селе(средне арифметическое - 73054.0, медиана - 71621.0).
#
# Можно сделать вывод, что чем ближе к Санкт-Петербургу находится поселение - тем выше цена квартир.
#
# ________________________<b>Как же стоимость объектов зависит от их расстояния до центра города?</b>________________________
#
# ![image-52.png](attachment:image-52.png)
#
# Чем дальше от центра, тем дешевле стоимость жилья. Пригороды Санкт-Петербурга находятся на расстоянии до 11км. от центра, поэтому можно понять небольшой рост цены за жильё в отметке от 3 до 4км - это близко к городу и жить там могут люди, работающие в самом городе.
#
# После отметки в 4 км - цена резко падает и, начиная с 9 км от центра, цена на жильё примерно одинаковая, бывают моменты когда она растёт, но это незначительно, потому что всё-равно падает.

# %% [markdown]
# ## **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
#
#
# <div class="alert alert-info"> __UPD__ Добавила этот пункт _6.2_, потому что было очень интересно - а влияет ли количество фотографий на продажу квартир (total_images) </div>
