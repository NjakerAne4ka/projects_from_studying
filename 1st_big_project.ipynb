# %% [markdown]
# <div  style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
#
# **Привет!**
#
# Меня зовут Василий Митров и я буду проверять твой проект. Предлагаю общаться на «ты». Если это неприемлемо, то дай мне знать и мы перейдем на «вы». Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных.
#
# Для удобства я оставлю комментарии в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Пожалуйста, не перемещай, не изменяй и не удаляй их - так наше общение будет более продуктивным. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# ✍ Так выделены самые важные замечания. Без их отработки проект не будет принят. При проверке я обращаю внимание не только на код, но и на интерпретацию и анализ результатов, а также соответствие данных техническому заданию.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 📝 Так выделены небольшие замечания или рекомендации. Постарайся, пожалуйста, учесть эти комментарии в этом проекте или в будущих проектах.
# </div>
#
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 👍 Так выделены все остальные комментарии, включая рекомендации, позитивные моменты или какие-то рассуждения и пояснения.
# </div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Например, вот так. Также, если есть какие-то вопросы, или что-то осталось непонятным по ревью - спрашивай в таких блоках и я постараюсь дать ответ.
# </div>
#
# ---

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Исследовательский-анализ-успешности-игр" data-toc-modified-id="Исследовательский-анализ-успешности-игр-0"><span class="toc-item-num">0&nbsp;&nbsp;</span>Исследовательский анализ успешности игр</a></span></li><li><span><a href="#Открываю-файл-с-данными-и-изучаю-общую-информацию" data-toc-modified-id="Открываю-файл-с-данными-и-изучаю-общую-информацию-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Открываю файл с данными и изучаю общую информацию</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Для-начала-поставлю-названия-столбцов-в-нижний-регистр." data-toc-modified-id="Для-начала-поставлю-названия-столбцов-в-нижний-регистр.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Для начала поставлю названия столбцов в нижний регистр.</a></span></li><li><span><a href="#Сначала-разберусь-со-столбиками-name-(название-игры)-и-genre-(жанр-игры)" data-toc-modified-id="Сначала-разберусь-со-столбиками-name-(название-игры)-и-genre-(жанр-игры)-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Сначала разберусь со столбиками name (название игры) и genre (жанр игры)</a></span></li><li><span><a href="#user_score-(оценка-пользователей)" data-toc-modified-id="user_score-(оценка-пользователей)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>user_score (оценка пользователей)</a></span></li><li><span><a href="#critic_score-(оценка-критиков)" data-toc-modified-id="critic_score-(оценка-критиков)-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>critic_score (оценка критиков)</a></span></li><li><span><a href="#year_of_release-(год-выпуска)" data-toc-modified-id="year_of_release-(год-выпуска)-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>year_of_release (год выпуска)</a></span></li><li><span><a href="#rating-(рейтинг-от-организации-ESRB)" data-toc-modified-id="rating-(рейтинг-от-организации-ESRB)-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>rating (рейтинг от организации ESRB)</a></span></li><li><span><a href="#na_sales-(продажи-в-Северной-Америке)" data-toc-modified-id="na_sales-(продажи-в-Северной-Америке)-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>na_sales (продажи в Северной Америке)</a></span></li><li><span><a href="#eu_sales-(продажи-в-Европе)" data-toc-modified-id="eu_sales-(продажи-в-Европе)-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>eu_sales (продажи в Европе)</a></span></li><li><span><a href="#jp_sales-(продажи-в-Японии)" data-toc-modified-id="jp_sales-(продажи-в-Японии)-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>jp_sales (продажи в Японии)</a></span></li><li><span><a href="#other_sales-(продажи-в-других-странах)" data-toc-modified-id="other_sales-(продажи-в-других-странах)-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>other_sales (продажи в других странах)</a></span></li><li><span><a href="#sales_grouped---Посчитать-суммарные-продажи-во-всех-регионах" data-toc-modified-id="sales_grouped---Посчитать-суммарные-продажи-во-всех-регионах-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>sales_grouped - Посчитать суммарные продажи во всех регионах</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-2.12"><span class="toc-item-num">2.12&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Посмотреть,-сколько-игр-выпускалось-в-разные-годы.-Важны-ли-данные-за-все-периоды?" data-toc-modified-id="Посмотреть,-сколько-игр-выпускалось-в-разные-годы.-Важны-ли-данные-за-все-периоды?-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Посмотреть, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?</a></span></li><li><span><a href="#Работа-с-платформами-и-поиск-ответов-на-вопросы-по-лучшей-из-представленных" data-toc-modified-id="Работа-с-платформами-и-поиск-ответов-на-вопросы-по-лучшей-из-представленных-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Работа с платформами и поиск ответов на вопросы по лучшей из представленных</a></span><ul class="toc-item"><li><span><a href="#Выбрать-платформы-с-наибольшими-суммарными-продажами-и-построить-распределение-по-годам.-За-какой-характерный-срок-появляются-новые-и-исчезают-старые-платформы?" data-toc-modified-id="Выбрать-платформы-с-наибольшими-суммарными-продажами-и-построить-распределение-по-годам.-За-какой-характерный-срок-появляются-новые-и-исчезают-старые-платформы?-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Выбрать платформы с наибольшими суммарными продажами и построить распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?</a></span></li><li><span><a href="#Какие-платформы-лидируют-по-продажам,-растут-или-падают?-Выбрать-несколько-потенциально-прибыльных-платформ" data-toc-modified-id="Какие-платформы-лидируют-по-продажам,-растут-или-падают?-Выбрать-несколько-потенциально-прибыльных-платформ-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Какие платформы лидируют по продажам, растут или падают? Выбрать несколько потенциально прибыльных платформ</a></span></li><li><span><a href="#Построить-боксплот-по-глобальным-продажам-игр-в-разбивке-по-платформам.-Описать-результат." data-toc-modified-id="Построить-боксплот-по-глобальным-продажам-игр-в-разбивке-по-платформам.-Описать-результат.-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Построить боксплот по глобальным продажам игр в разбивке по платформам. Описать результат.</a></span></li><li><span><a href="#Посмотреть,-как-влияют-на-продажи-внутри-одной-популярной-платформы-отзывы-пользователей-и-критиков.-Построить-диаграмму-рассеяния-и-посчитать-корреляцию-между-отзывами-и-продажами.-Сформулировать-выводы." data-toc-modified-id="Посмотреть,-как-влияют-на-продажи-внутри-одной-популярной-платформы-отзывы-пользователей-и-критиков.-Построить-диаграмму-рассеяния-и-посчитать-корреляцию-между-отзывами-и-продажами.-Сформулировать-выводы.-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Посмотреть, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Построить диаграмму рассеяния и посчитать корреляцию между отзывами и продажами. Сформулировать выводы.</a></span></li></ul></li><li><span><a href="#Работа-с-платформами-и-поиск-ответов-на-вопросы-по-остальным-платформам" data-toc-modified-id="Работа-с-платформами-и-поиск-ответов-на-вопросы-по-остальным-платформам-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Работа с платформами и поиск ответов на вопросы по остальным платформам</a></span><ul class="toc-item"><li><span><a href="#Соотнести-выводы-с-продажами-игр-на-других-платформах." data-toc-modified-id="Соотнести-выводы-с-продажами-игр-на-других-платформах.-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Соотнести выводы с продажами игр на других платформах.</a></span></li><li><span><a href="#Посмотреть-на-общее-распределение-игр-по-жанрам." data-toc-modified-id="Посмотреть-на-общее-распределение-игр-по-жанрам.-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Посмотреть на общее распределение игр по жанрам.</a></span></li></ul></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Портреты-пользователей-каждого-региона-(na,-eu,-jp)" data-toc-modified-id="Портреты-пользователей-каждого-региона-(na,-eu,-jp)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Портреты пользователей каждого региона (na, eu, jp)</a></span><ul class="toc-item"><li><span><a href="#Северная-Америка" data-toc-modified-id="Северная-Америка-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Северная Америка</a></span></li><li><span><a href="#Европа" data-toc-modified-id="Европа-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Европа</a></span></li><li><span><a href="#Япония" data-toc-modified-id="Япония-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Япония</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Гипотезы" data-toc-modified-id="Гипотезы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Гипотезы</a></span><ul class="toc-item"><li><span><a href="#средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые" data-toc-modified-id="средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>средние пользовательские рейтинги платформ Xbox One и PC одинаковые</a></span></li><li><span><a href="#средние-пользовательские-рейтинги-жанров-Action-и-Sports-разные" data-toc-modified-id="средние-пользовательские-рейтинги-жанров-Action-и-Sports-разные-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>средние пользовательские рейтинги жанров Action и Sports разные</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Чек лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# ## Исследовательский анализ успешности игр

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
#
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».
#
# <b> Цель: </b>
#
# Нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании на последующий год (2017).
#
# <b> Описание данных: </b>
#
# Также я должна помнить, что данные за 2016 год предоставлены не все.
#
# - Name — название игры
#
# - Platform — платформа
#
# - Year_of_Release — год выпуска
#
# - Genre — жанр игры
#
# - NA_sales — продажи в Северной Америке (миллионы проданных копий)
#
# - EU_sales — продажи в Европе (миллионы проданных копий)
#
# - JP_sales — продажи в Японии (миллионы проданных копий)
#
# - Other_sales — продажи в других странах (миллионы проданных копий)
#
# - Critic_Score — оценка критиков (максимум 100)
#
# - User_Score — оценка пользователей (максимум 10)
#
# - Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# <b>NB:</b> Данные за 2016 год могут быть не полными.
#
# <b> План работы </b>
#
# <b>1. Открыть файл с данными и изучить общую информацию</b>
#
# <b>2. Подготовить данные:</b>
#
#     - Заменить названия столбцов и строки в отдельных столбцах (привести к нижнему регистру);
#
#     - Преобразовать данные в нужные типы. Описать, в каких столбцах я заменила тип данных и почему;
#
#     - Обработать пропуски при необходимости:
#
#         - Объяснить, почему я заполнила пропуски определённым образом или почему не стала это делать;
#
#         - Описать причины, которые могли привести к пропускам;
#
#     - Обратить внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разобрать это значение и описать, как его обработать;
#
#     - Посчитать суммарные продажи во всех регионах и записать их в отдельный столбец.
#
# <b> 3. Провести исследовательский анализ данных и ответить на следующие возникшие вопросы: </b>
#
# - Сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
#
# - Как менялись продажи по платформам? Выбрать платформы с наибольшими суммарными продажами и построить распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
#
# - Взять данные за соответствующий актуальный период. Актуальный период определить в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
#
# - Не учитывать в работе данные за предыдущие годы.
#
# - Какие платформы лидируют по продажам, растут или падают? Выбрать несколько потенциально прибыльных платформ.
#
# - Построить график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Описать результат.
#
# - Посмотреть, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Построить диаграмму рассеяния и посчитать корреляцию между отзывами и продажами. Сформулировать выводы.
#
# - Соотнести выводы с продажами игр на других платформах.
#
# - Общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# <b> 4. Составить портрет пользователя каждого региона </b>
#
# Определить для пользователя каждого региона (NA, EU, JP):
#
#     - Самые популярные платформы (топ-5). Описать различия в долях продаж.
#
#     - Самые популярные жанры (топ-5). Пояснить разницу.
#
#     - Влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
# <b> 5. Проверить гипотезы </b>
#
# - Являются ли одинаковыми средние пользовательские рейтинги платформ Xbox One и PC;
#
# - Являются ли разными средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования»);
#
# - Пояснить:
#
#     - Как я сформулировала нулевую и альтернативную гипотезы;
#
#     - Какой критерий я применила для проверки гипотез и почему.
#
# <b> 6. Написать общий вывод </b>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Отличное вступление к проекту!
# </div>

# %% [markdown]
# ## Открываю файл с данными и изучаю общую информацию

# %%
import pandas as pd # импортирую библиотеку pandas
import seaborn as sns # в будущем понадобилось
import numpy as np # в будущем понадобилось
import matplotlib.pyplot as plt # в будущем понадобилось
import scipy.stats as stats # если понадобиться работать с квантилями
import seaborn as sns # если понадобиться

games = pd.read_csv('/datasets/games.csv')# прочитываю csv-файл
def printing_needable(games):
    return (
        print('Первые 15 строк:'), display(games.head(15)), print(),
        print('Последние 15 строк'), display(games.tail(15)), print(),
        print('Общая информация о данных:'),  print(), print(games.info()), print(),
        print('Дубликатов найдено:', games.duplicated().sum()), print(),
    )

printing_needable(games);
# Out:
# Первые 15 строк:
#                            Name Platform  Year_of_Release         Genre  \
# 0                    Wii Sports      Wii           2006.0        Sports
# 1             Super Mario Bros.      NES           1985.0      Platform
# 2                Mario Kart Wii      Wii           2008.0        Racing
# 3             Wii Sports Resort      Wii           2009.0        Sports
# 4      Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                        Tetris       GB           1989.0        Puzzle
# 6         New Super Mario Bros.       DS           2006.0      Platform
# 7                      Wii Play      Wii           2006.0          Misc
# 8     New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                     Duck Hunt      NES           1984.0       Shooter
# 10                   Nintendogs       DS           2005.0    Simulation
# 11                Mario Kart DS       DS           2005.0        Racing
# ...

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Совет: выносить загрузку датасета в отдельную ячейку в соответствии с PEP8.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
#
# Привет, я Аня Мисюра. Давай лучше на ты - так привычнее)
#
# Немного почитала - постаралась сделать красивый код.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Приятно познакомиться :)
# </div>

# %%
games.hist(figsize=(10, 15), color='green');

# %%
colours = ['#00992b', '#d6e3b1'] 
sns.heatmap(games.isnull(), cmap=sns.color_palette(colours));

# %%
# что-то тут прям не так, составлю-ка список недостающих записей для каждого признака
print('Количество пропущенных данных в цифрах', '\n')
print(games.isnull().sum())
print( '\n', 'Количество пропущенных данных в процентах', '\n')
for i in games.columns:
    pct_missing = np.mean(games[i].isnull())
    print('{} - {}%'.format(i, round(pct_missing*100)))
# Out:
# Количество пропущенных данных в цифрах
#
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64
#
#  Количество пропущенных данных в процентах
#
# Name - 0%
# Platform - 0%
# Year_of_Release - 2%
# Genre - 0%
# NA_sales - 0%
# EU_sales - 0%
# JP_sales - 0%
# Other_sales - 0%
# Critic_Score - 51%
# User_Score - 40%
# Rating - 40%

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Хороший способ посмотреть на долю пропусков!
#
# Держи еще один 😊
#
# `pd.DataFrame(round(df.isna().mean()*100,1)).style.background_gradient('coolwarm')`
# </div>

# %%
pd.DataFrame(round(games.isna().mean()*100,1)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_23549_row0_col0,#T_23549_row1_col0,#T_23549_row3_col0,#T_23549_row4_col0,#T_23549_row5_col0,#T_23549_row6_col0,#T_23549_row7_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_23549_row2_col0{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_23549_row8_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_23549_row9_col0{
#             background-color:  #f08b6e;
#             color:  #000000;
#         }#T_23549_row10_col0{
#             background-color:  #ef886b;
#             color:  #000000;
#         }</style><table id="T_23549_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_23549_level0_row0" class="row_heading level0 row0" >Name</th>
# ...

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
# Красивое! Более удобно для визуального акцентирования! Возьму на заметку.
# </div>

# %% [markdown]
# Проверю-ка данные на уникальность.

# %%
games.nunique()
# Out:
# Name               11559
# Platform              31
# Year_of_Release       37
# Genre                 12
# NA_sales             402
# EU_sales             307
# JP_sales             244
# Other_sales          155
# Critic_Score          82
# User_Score            96
# Rating                 8
# dtype: int64

# %% [markdown]
# ### Вывод:
#
# __Есть столбцы где, на первый взгляд, всё в порядке__
#
# - Name (название игры) - тип - object, но есть 2 уникальных значений и их надо будет проверить;
#
# - Platform (платформа) - тип - object;
#
# - Genre (жанр игры) - тип - object, но есть 2 уникальных значений и их надо будет проверить;
#
# __Но также есть столбцы с рядом проблем, которые необходимо устранить (по возможности) для удобного и адекватного анализа.__
#
# - Year_of_Release (год выпуска) - тип - float, 269 пропущенных значений = 2%, так как в этом столбце описаны года, то логичным будет изменить тип данных на int, т.е. целочисленное;
#
# - NA_sales (продажи в Северной Америке) - тип - float, пропущенных значений не выявлено, но есть большое количество значений "0.0" - надо посмотреть, что тут не так;
#
# - EU_sales (продажи в Европе) - тип - float, всё точно также, как и в _NA_sales_;
#
# - JP_sales (продажи в Японии) - тип - float, всё точно также, как и в _NA_sales_;
#
# - Other_sales (продажи в других странах) - тип - float, всё точно также, как и в _NA_sales_;
#
# - Critic_Score (оценка критиков) - тип - float, много пропущенных значений - 8578 = 51%, много значений _NaN_;
#
# - User_Score (оценка пользователей) - тип - object, 6701 пропущенных значений = 40% и много значений _NaN_, надо посмотреть, может необходимо изменить тип данных;
#
# - Rating (рейтинг от организации ESRB) - тип - object, 6766 пропущенных значений = 40% и много значений _NaN_;
#
# __Общие замечания по всем столбцам__
#
# В столбцах User_Score и Rating отсутствует практически половина данных - 40%, а в Critic_Score - чуть больше половины - 51%! Надо проверить эти столбцы, может, я смогу найти вразумительное объяснение почему в них отсутствуют данные.
#
# Явные дубликаты не найдены и это уже неплохо.
#
# Необходимо привести названия столбцов в нижний регистр, чтобы не создавать проблем для считывания информации и для удобства работы с датой.
#
# После этого нужно проверить на данные в столбцах под вопросом.
#
# user_score имеет непонятное значение tbd
#
# rating - непонятные буквы, надо понять что это и как работает

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Хорошая вводная часть.
#
# Рекомендую создать универсальную функцию, которая будет принимать на вход датафрейм, а на выходе она будет выводить всего нужные характеристики, например, head, describe, info, дубликаты и т.п.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
#
# Так, я ещё с прошлого проекта заметила, что у меня всё плохо с функциями - где-то доходит как и что сделать, а где-то не допирает что я делаю не так. Что мне с этим делать - как лучше набить руку (мб какие песочницы есть кодерские?) и что почитать?
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Вот такая книга про язык Python. Она очень классная: https://monster-book.com/avtomatizaciya-zadach-s-python
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.2</b>
#
# Спасибо)
#
# Буду постигать)
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Для начала поставлю названия столбцов в нижний регистр.

# %%
games.columns = games.columns.str.lower()
display(games.head());
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# К общепринятому стилю можно привести еще вот таким методом:</font><br>
# `df.columns = df.columns.str.lower()`
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
# Так конечно удобнее и быстрее! Поэтому переделала на одну строку)
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# :))
# </div>

# %% [markdown]
# Тажке для удобства работы с данными в колонках, поставлю значения строк __name, platform, genre и rating__ в нижний регистр

# %%
lower_lines = ['name','platform','genre','rating']
for column in lower_lines:
    games[column] = games[column].str.lower()
display(games.head());
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                wii sports      wii           2006.0        sports     41.36
# 1         super mario bros.      nes           1985.0      platform     29.08
# 2            mario kart wii      wii           2008.0        racing     15.68
# 3         wii sports resort      wii           2009.0        sports     15.61
# 4  pokemon red/pokemon blue       gb           1996.0  role-playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      e
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      e
# 3     10.93      3.28         2.95          80.0          8      e
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
print(games.platform.unique())
# Out:
# ['wii' 'nes' 'gb' 'ds' 'x360' 'ps3' 'ps2' 'snes' 'gba' 'ps4' '3ds' 'n64'
#  'ps' 'xb' 'pc' '2600' 'psp' 'xone' 'wiiu' 'gc' 'gen' 'dc' 'psv' 'sat'
#  'scd' 'ws' 'ng' 'tg16' '3do' 'gg' 'pcfx']

# %%
# Что это за значение - 2600?
games.loc[games['platform'] == '2600']
# Out:
#                         name platform  year_of_release     genre  na_sales  \
# 89                   pac-man     2600           1982.0    puzzle      7.28
# 240                 pitfall!     2600           1981.0  platform      4.21
# 262                asteroids     2600           1980.0   shooter      4.00
# 546          missile command     2600           1980.0   shooter      2.56
# 609           space invaders     2600              NaN   shooter      2.36
# ...                      ...      ...              ...       ...       ...
# 8741                    klax     2600           1989.0    puzzle      0.14
# 9095                   krull     2600           1982.0    action      0.13
# 9487   realsports volleyball     2600           1981.0    sports      0.12
# 11747         super football     2600           1987.0    sports      0.07
# 11777         super baseball     2600           1987.0    sports      0.07
#
# ...

# %% [markdown]
# Игры со значением 2600 - это игры, вышедшие на Atari 2600, значит, эти значения лучше переименовать на __atari2600__

# %%
games['platform'] = games['platform'].replace('2600', 'atari2600')
print(games.platform.unique())
# Out:
# ['wii' 'nes' 'gb' 'ds' 'x360' 'ps3' 'ps2' 'snes' 'gba' 'ps4' '3ds' 'n64'
#  'ps' 'xb' 'pc' 'atari2600' 'psp' 'xone' 'wiiu' 'gc' 'gen' 'dc' 'psv'
#  'sat' 'scd' 'ws' 'ng' 'tg16' '3do' 'gg' 'pcfx']

# %%
# резервная копия для проверки всего что надо
games2 = pd.read_csv('/datasets/games.csv')
# код для проверки games = с чем я работаю, а games2 = нетронутая версия
# games.shape[0] / games2.shape[0]

# %% [markdown]
# Сначала рассмотрю нижеприведённые столбцы и постараюсь решить возникшие в них проблемы.
#
# - name (название игры) и genre (жанр игры) - есть два пропущенных значения, которые лучше будет убрать, чтобы они не "мешали" в последющей работе;
#
# - user_score (оценка пользователей) - тип - object, 6701 пропущенных значений и много значений _NaN_;
#
# - critic_score (оценка критиков) - тип - float, много пропущенных значений - 8578, много значений _NaN_;
#
# - year_of_release (год выпуска) - тип - float, 269 пропущенных значений, изменить тип на int;
#
#
#
# - rating (рейтинг от организации ESRB) - тип - object, 6766 пропущенных значений и много значений _NaN_;
#
#
#
# - na_sales (продажи в Северной Америке) - тип - float, есть большое количество значений "0.0" - надо посмотреть, что тут не так;
#
# - eu_sales (продажи в Европе) - тип - float, всё точно также, как и в _NA_sales_;
#
# - jp_sales (продажи в Японии) - тип - float, всё точно также, как и в _NA_sales_;
#
# - other_sales (продажи в других странах) - тип - float, всё точно также, как и в _NA_sales_;

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Молодец, что не забываешь про явные дубликаты.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Но, также мы можем проверить наличие неявных дубликатов. Неявные дубликаты могут появиться в случаях, когда данные собирались из разных источников или в системе были какие-то сбои при логировании. Я пометил этот момент красным, для того, что бы мы попрактиковались в этом, также это пригодится в следующих проектах.
#
# Сделать это можно так: мы уже привели названия столбцов к нижнему регистру, теперь проведем вот такую проверку `data[data[['name', 'platform','year_of_release']].duplicated(keep=False)]`
#
# Попробуй, пожалуйста, реализовать и сделать заключение, есть ли неявные дубликаты и что мы можем с ними сделать :)
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
# Пробую. <b> UPD </b> - о, круто! Спасибо за рекомендацию - так всё красивей)
# </div>

# %%
games[games[['name', 'platform', 'year_of_release']].duplicated(keep=False)]
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 604    madden nfl 13      ps3           2012.0  sports      2.11      0.22
# 659              NaN      gen           1993.0     NaN      1.78      0.53
# 14244            NaN      gen           1993.0     NaN      0.00      0.00
# 16230  madden nfl 13      ps3           2012.0  sports      0.00      0.01
#
#        jp_sales  other_sales  critic_score user_score rating
# 604        0.00         0.23          83.0        5.5      e
# 659        0.00         0.08           NaN        NaN    NaN
# 14244      0.03         0.00           NaN        NaN    NaN
# 16230      0.00         0.00          83.0        5.5      e

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# Найдено небольшое количество неявнях дубликатов по колонкам 'name', 'platform' и 'year_of_release', лучше их удалить, чтобы не было сумятицы из-за одинаковых данных.

# %%
key = ['name', 'platform', 'year_of_release']
games = games.drop_duplicates(subset=key)

# %%
games.shape[0] / games2.shape[0]
# Out:
# 0.9998803469937182

# %% [markdown]
# ### Сначала разберусь со столбиками name (название игры) и genre (жанр игры)

# %%
games.dropna(subset=['name', 'genre'], inplace=True)
print('Количество пропусков в name:', games['name'].isnull().sum())
print('Количество пропусков в genre:', games['genre'].isnull().sum())
# Out:
# Количество пропусков в name: 0
# Количество пропусков в genre: 0

# %%
print('Было:', games2.shape[0])
# Out:
# Было: 16715

# %%
print('Стало:', games.shape[0])
# Out:
# Стало: 16712

# %%
games.shape[0] / games2.shape[0]
# Out:
# 0.9998205204905773

# %% [markdown]
# Удалён округлённо 0.01% от общего датасета, но это не критично. Двигаюсь дальше.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Верно, доля пропусков здесь менее 5% и для экономии времени их можно удалить.
# </div>

# %% [markdown]
# ### user_score (оценка пользователей)

# %%
print(games['user_score'].head())
# Out:
# 0      8
# 1    NaN
# 2    8.3
# 3      8
# 4    NaN
# Name: user_score, dtype: object

# %% [markdown]
# Так как тут числа со значениями после точки, то надо изменить тип с object на float

# %%
games['user_score'] = np.floor(pd.to_numeric(games['user_score'], errors='coerce')).astype(float)
print(games['user_score'].head())
print(games['user_score'].describe())
games['user_score'].dtype
# Out:
# 0    8.0
# 1    NaN
# 2    8.0
# 3    8.0
# 4    NaN
# Name: user_score, dtype: float64
# count    7589.000000
# mean        6.678877
# std         1.516837
# min         0.000000
# 25%         6.000000
# 50%         7.000000
# 75%         8.000000
# max         9.000000
# Name: user_score, dtype: float64
# dtype('float64')

# %% [markdown]
# Глядя на ответ на Метакритике (https://www.metacritic.com/faq#item13), tbd означает __To Be Determined__, т.е. если в их базе нет как минимум 4х отзывов на оцениваемое произведение, в моём случае игр, - выставляется данное значение. Дословно переводится как __до определения__, т.е. до момент как будет достаточное количество отзывов (больше 4х).
# Если исходить из логики того, что игроки той же Северной Америки и Европы неплохо владеют а.я., потому что он необходим для той же работы, то в Японии немного дело обстоит иначе - английский не самый распространённый язык в этой стране (сделала вывод по вот этой статье https://www.nippon.com/ru/japan-data/h01509/) и его популярность только снижается. Из этого следует вывод, что мало кто из игроков японцев будет писать отзывы на Метакритике - скорее всего это будут другие платформы, но на японском зяыке.
#
# Получается, что данные с tbd и данные с NaN это, по сути, одно и тоже. Пока переделаю их на "NaN".

# %%
games['user_score'] = games['user_score'].replace('tbd', np.NaN)
print('Количество пропусков =', games['user_score'].isnull().sum())
print()
print(games['user_score'].describe())
print()
print(games['user_score'].head())
# Out:
# Количество пропусков = 9123
#
# count    7589.000000
# mean        6.678877
# std         1.516837
# min         0.000000
# 25%         6.000000
# 50%         7.000000
# 75%         8.000000
# max         9.000000
# Name: user_score, dtype: float64
#
# 0    8.0
# 1    NaN
# 2    8.0
# 3    8.0
# 4    NaN
# Name: user_score, dtype: float64

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Верно, `tbd` означает `To Be Determined`, т.к. игра ещё не выпущена. Тут можно заменить заглушкой, а можно привести в nan
# </div>

# %% [markdown]
# ### critic_score (оценка критиков)

# %%
print(games['critic_score'].head())
# Out:
# 0    76.0
# 1     NaN
# 2    82.0
# 3    80.0
# 4     NaN
# Name: critic_score, dtype: float64

# %% [markdown]
# Смотря на данные на Метакритике (https://www.metacritic.com/about-metascores) можно понять как устроена скоринговая система. Зная о факте, что Метакритик существет с нулевых годов 21 века, проверю-ка - все-ли игры с NaN старые.

# %%
games.query('critic_score.isnull()')
# Out:
#                                 name platform  year_of_release         genre  \
# 1                  super mario bros.      nes           1985.0      platform
# 4           pokemon red/pokemon blue       gb           1996.0  role-playing
# 5                             tetris       gb           1989.0        puzzle
# 9                          duck hunt      nes           1984.0       shooter
# 10                        nintendogs       ds           2005.0    simulation
# ...                              ...      ...              ...           ...
# 16710  samurai warriors: sanada maru      ps3           2016.0        action
# 16711               lma manager 2007     x360           2006.0        sports
# 16712        haitaka no psychedelica      psv           2016.0     adventure
# 16713               spirits & spells      gba           2003.0      platform
# 16714            winning post 8 2016      psv           2016.0    simulation
#
# ...

# %% [markdown]
# Нет, пропуски не связаны с годом выпуска игры.

# %%
print('Количество пропусков =', games['critic_score'].isnull().sum())
print()
print(games['critic_score'].describe())
print()
print(games['critic_score'].head())
# Out:
# Количество пропусков = 8576
#
# count    8136.000000
# mean       68.965954
# std        13.938153
# min        13.000000
# 25%        60.000000
# 50%        71.000000
# 75%        79.000000
# max        98.000000
# Name: critic_score, dtype: float64
#
# 0    76.0
# 1     NaN
# 2    82.0
# 3    80.0
# 4     NaN
# Name: critic_score, dtype: float64

# %% [markdown]
# В user_score и critic_score больше всего пропущенных данных, для того, чтобы нормально потом считывать и работать с данными приведу все NaN значения к 1 - она будет индикатором того, что это отсутствие значения. Заполнять такое количество данных медианным значением я считаю не хорошей стратегией, потому что данные могут исказиться.

# %%
games['user_score'] = games['user_score'].fillna(101)
print('Количество пропусков в user_score - {}'.format(games['user_score'].isnull().sum()))
games['critic_score'] = games['critic_score'].fillna(101)
print('Количество пропусков в critic_score - {}'.format(games['critic_score'].isnull().sum()))
# Out:
# Количество пропусков в user_score - 0
# Количество пропусков в critic_score - 0

# %%
games.shape[0] / games2.shape[0]
# Out:
# 0.9998205204905773

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Решение допустимое, но может привести к проблемам при анализе влияния отзывов на продажи, нужно отследить это.
# </div>

# %% [markdown]
# ### year_of_release (год выпуска)

# %% [markdown]
# Сначала меняю тип с float на int

# %%
print(games['year_of_release'].describe())
print()
print('Количество пропусков:', games['year_of_release'].isnull().sum())
unique_year = games['year_of_release']
games['year_of_release'].plot(kind='box')
plt.show()
games['year_of_release'].hist(color='green');
#pd.set_option('display.max_rows', None)
#games_2columns = games[['year_of_release', 'name']]
#print('Игры и года', '\n', games_2columns)
# Out:
# count    16443.000000
# mean      2006.485921
# std          5.875546
# min       1980.000000
# 25%       2003.000000
# 50%       2007.000000
# 75%       2010.000000
# max       2016.000000
# Name: year_of_release, dtype: float64
#
# Количество пропусков: 269

# %% [markdown]
# Просмотрев обе колонки по имени и году релиза(скрыла хэштегом за дальнейшей ненадобностью - games_2columns) я сделала вывод, что можно удалить пропуски в year_of_release.

# %%
games.dropna(subset=['year_of_release'], inplace=True)
games['year_of_release'] = np.floor(pd.to_numeric(games['year_of_release'], errors='coerce')).astype('Int64')
print(games['year_of_release'].dtype)
print('Количество пропусков в year_of_release - {}'.format(games['year_of_release'].isnull().sum()))
# Out:
# Int64
# Количество пропусков в year_of_release - 0

# %%
games.shape[0] / games2.shape[0]
# Out:
# 0.9837271911456775

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Здесь пропуски также можно изначально удалить за малой долей.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
#
# Мне что-то смелости сначало не хватило Ж)
#
# Удалила, чтобы не бесили)
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# 5 - 7 процентов это допустимый порог, но надо понимать природу пропусков и мешают ли они нам.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.2</b>
#
# Буду стараться постигать что кого)
# </div>

# %% [markdown]
# ### rating (рейтинг от организации ESRB)

# %% [markdown]
# Смотря на то, что означают буквы на сайте ESRB(https://www.esrb.org/ratings-guide/), можно сделать вывод, что пропущенные игры скорее всего были после создания ESRB (1994год). Проверяю на самом ли деле игры с NaN вышли до 1994 года.

# %%
games.query('rating.isnull()')
# Out:
#                                 name platform  year_of_release         genre  \
# 1                  super mario bros.      nes             1985      platform
# 4           pokemon red/pokemon blue       gb             1996  role-playing
# 5                             tetris       gb             1989        puzzle
# 9                          duck hunt      nes             1984       shooter
# 10                        nintendogs       ds             2005    simulation
# ...                              ...      ...              ...           ...
# 16710  samurai warriors: sanada maru      ps3             2016        action
# 16711               lma manager 2007     x360             2006        sports
# 16712        haitaka no psychedelica      psv             2016     adventure
# 16713               spirits & spells      gba             2003      platform
# 16714            winning post 8 2016      psv             2016    simulation
#
# ...

# %% [markdown]
# Нет, пропуски не связаны с годом выпуска игры. Проверю уникальные значения.

# %%
unique_rating = games['rating']
print(unique_rating.sort_values().unique())
print('Количество пропусков:', games['rating'].isnull().sum())
# Out:
# ['ao' 'e' 'e10+' 'ec' 'k-a' 'm' 'rp' 't' nan]
# Количество пропусков: 6676

# %% [markdown]
# Следуя логике выставления рейтинга выходит такая картина.
#
# __AO__ - Подходит для взрослых старше 18 лет.
#
# __E__ - Подходит для всех возрастных категорий.
#
# __E10+__ - Подходит для лиц старше 10 лет.
#
# __EC__ - Для детей младшего возраста.
#
# __K-A__ - Для всех от 10 лет и старше.
#
# __M__ - Подходит для лиц старше 17 лет.
#
# __RP__ - Категория ещё не присвоена.
#
# __T__ - Подходит для лиц старше 13 лет.
#
# nan - наши пропущенные значения.
#
# ![image-2.png](attachment:image-2.png)
#
# Согласно данным с указанного выше сайта, можно увидеть, что __K-A__ нет. И действительно, он был заменён на __Everyone__, т.е. __E__ 1 января 1998года, соответственно, первые обозначения необходимо заменить на вторые. Воспользуюсь rating pending и заменю пропуски на него, потому что это логично - у таких игр пока нет рейтинга (из-за отсутствия необходимого количества голосов).
#
# После этого сделаю отдельный столбец с разъяснением возрастных групп, для последующего удобства работы с данными через список.

# %%
games.loc[games['rating'] == 'k-a']
# Out:
#                      name platform  year_of_release     genre  na_sales  \
# 656        theme hospital       pc             1997  strategy      2.30
# 903    parappa the rapper       ps             1996      misc      0.26
# 16681             worms 2       pc             1997  strategy      0.00
#
#        eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 656        0.10      0.00         0.00         101.0         9.0    k-a
# 903        0.16      1.46         0.03          92.0         7.0    k-a
# 16681      0.01      0.00         0.00         101.0         8.0    k-a

# %%
games['rating'] = games['rating'].replace('k-a', 'e')
games['rating'] = games['rating'].fillna('rp')
print(unique_rating.sort_values().unique())
# Out:
# ['ao' 'e' 'e10+' 'ec' 'm' 'rp' 't']

# %%
rating_years = {'ao':'с 18 лет',
    'e':'Для всех',
        'e10+':'с 10 лет',
            'ec':'до 10лет',
                'm':'с 17 лет',
                    'rp':'нет категории',
                        't': 'с 13 лет'}
games['rating_meaning'] = games[games['rating'].notnull()]['rating'].map(rating_years)

# %%
print('Количество пропусков:', games['rating'].isnull().sum())
games.head(10)
# Out:
# Количество пропусков: 0
#                         name platform  year_of_release         genre  \
# 0                 wii sports      wii             2006        sports
# 1          super mario bros.      nes             1985      platform
# 2             mario kart wii      wii             2008        racing
# 3          wii sports resort      wii             2009        sports
# 4   pokemon red/pokemon blue       gb             1996  role-playing
# 5                     tetris       gb             1989        puzzle
# 6      new super mario bros.       ds             2006      platform
# 7                   wii play      wii             2006          misc
# 8  new super mario bros. wii      wii             2009      platform
# 9                  duck hunt      nes             1984       shooter
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     41.36     28.96      3.77         8.45          76.0         8.0      e
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Все верно, ты молодец! Пропуски в этой колонке не являются просто ошибкой заполнения данных, а несут определенную информацию. Что бы проанализировать ее, на пропуски следует поставить заглушку.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Совершенно верно! Я же оставил зеленый комментарий с похвалой выше :)
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.2</b>
#
# Я просто забыла удалить коммент Ж)
# </div>

# %% [markdown]
# ### na_sales (продажи в Северной Америке)

# %%
print(games['na_sales'].describe())
print()
games['na_sales'].plot(kind='box')
plt.show()
games['na_sales'].hist(bins=5, color='green', range=(0, 6));
# Out:
# count    16443.000000
# mean         0.264028
# std          0.818400
# min          0.000000
# 25%          0.000000
# 50%          0.080000
# 75%          0.240000
# max         41.360000
# Name: na_sales, dtype: float64

# %%
games['na_sales'].hist(bins=5, color='green', range=(20, 45));

# %%
games.head(20)
print('Количество пропусков:', games['na_sales'].isnull().sum())
# Out:
# Количество пропусков: 0

# %% [markdown]
# Между медианой(0.08) и средним(0.26) разница невелика, но есть что-то наподобие выбросов после "35".

# %% [markdown]
# ### eu_sales (продажи в Европе)

# %%
print(games['eu_sales'].describe())
print()
games['eu_sales'].plot(kind='box')
plt.show()
games['eu_sales'].hist(bins=5, color='green', range=(0, 5));
# Out:
# count    16443.000000
# mean         0.145939
# std          0.506731
# min          0.000000
# 25%          0.000000
# 50%          0.020000
# 75%          0.110000
# max         28.960000
# Name: eu_sales, dtype: float64

# %%
games['eu_sales'].hist(bins=5, color='green', range=(25, 35));

# %% [markdown]
# Между медианой(0.02) и средним(0.14) разница невелика, но есть что-то наподобие выбросов после "25".

# %% [markdown]
# ### jp_sales (продажи в Японии)

# %%
print(games['jp_sales'].describe())
print()
games['jp_sales'].plot(kind='box')
plt.show()
games['jp_sales'].hist(bins=5, color='green');
# Out:
# count    16443.000000
# mean         0.078492
# std          0.311109
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.040000
# max         10.220000
# Name: jp_sales, dtype: float64

# %%
games['jp_sales'].hist(bins=5, color='green', range=(4, 14));

# %% [markdown]
# Между медианой(0.0) и средним(0.07) есть разница, а ткаже выбросы после "10".

# %% [markdown]
# ### other_sales (продажи в других странах)

# %%
print(games['other_sales'].describe())
print()
games['other_sales'].plot(kind='box')
plt.show()
games['other_sales'].hist(bins=5, color='green', range=(0, 1.5));
# Out:
# count    16443.000000
# mean         0.047597
# std          0.188011
# min          0.000000
# 25%          0.000000
# 50%          0.010000
# 75%          0.030000
# max         10.570000
# Name: other_sales, dtype: float64

# %%
games['other_sales'].hist(bins=5, color='green', range=(7, 15));

# %% [markdown]
# ### sales_grouped - Посчитать суммарные продажи во всех регионах

# %% [markdown]
# Для этого необходимо сложить данные в колонках про продажи и сохраню результат в новую колонку __sales_grouped__

# %%
games['sales_grouped'] = games['na_sales'] + games['eu_sales'] + games['jp_sales'] + games['other_sales']

# %%
games.describe()
# Out:
#        year_of_release      na_sales      eu_sales      jp_sales  \
# count     16443.000000  16443.000000  16443.000000  16443.000000
# mean       2006.485921      0.264028      0.145939      0.078492
# std           5.875546      0.818400      0.506731      0.311109
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         other_sales  critic_score    user_score  sales_grouped
# count  16443.000000  16443.000000  16443.000000   16443.000000
# mean       0.047597     85.462507     58.196801       0.536055
# std        0.188011     18.707539     46.970684       1.558828
# min        0.000000     13.000000      0.000000       0.000000
# 25%        0.000000     71.000000      7.000000       0.060000
# ...

# %% [markdown]
# ### Вывод:

# %% [markdown]
# Теперь просмотрю, как теперь всё выглядит в итоге.

# %% [markdown]
# __Было вот так:__
#
# ![image.png](attachment:image.png)
#
# __А стало:__

# %%
print('Количество пропущенных данных в цифрах', '\n')
print(games.isnull().sum())
# Out:
# Количество пропущенных данных в цифрах
#
# name               0
# platform           0
# year_of_release    0
# genre              0
# na_sales           0
# eu_sales           0
# jp_sales           0
# other_sales        0
# critic_score       0
# user_score         0
# rating             0
# rating_meaning     0
# sales_grouped      0
# dtype: int64

# %% [markdown]
# __Было вот так:__
#
# ![image.png](attachment:image.png)
#
# __А стало:__

# %%
print( '\n', 'Количество пропущенных данных в процентах', '\n')
for i in games.columns:
    pct_missing = np.mean(games[i].isnull())
    print('{} - {}%'.format(i, round(pct_missing*100)))
# Out:
#  Количество пропущенных данных в процентах
#
# name - 0%
# platform - 0%
# year_of_release - 0%
# genre - 0%
# na_sales - 0%
# eu_sales - 0%
# jp_sales - 0%
# other_sales - 0%
# critic_score - 0%
# user_score - 0%
# rating - 0%
# rating_meaning - 0%
# sales_grouped - 0%

# %%
print('Первые 5 строк:'), display(games.head());
print()
print('Последние 5 строк'), display(games.tail());
# Out:
# Первые 5 строк:
#                        name platform  year_of_release         genre  na_sales  \
# 0                wii sports      wii             2006        sports     41.36
# 1         super mario bros.      nes             1985      platform     29.08
# 2            mario kart wii      wii             2008        racing     15.68
# 3         wii sports resort      wii             2009        sports     15.61
# 4  pokemon red/pokemon blue       gb             1996  role-playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      e
# 1      3.58      6.81         0.77         101.0       101.0     rp
# 2     12.76      3.79         3.29          82.0         8.0      e
# 3     10.93      3.28         2.95          80.0         8.0      e
# 4      8.89     10.22         1.00         101.0       101.0     rp
#
#   rating_meaning  sales_grouped
# 0       Для всех          82.54
# ...

# %% [markdown]
# **Вывод по предобработке данных**
#
# Названия всех столбцов и данные в колонках (_name(название), platform(платформа), genre(жанр игры) и rating(рейтинг)_) были поставлены в нижний регистр для более удобной работы с данными;
#
# В колонках _name (название игры) и genre (жанр игры)_ было удалено 2 строки с пропущенными данными - на общее количество данных они не сильно повлияли, а для последующего анализа данные будет исследовать проще;
#
# Так как в _user_score (оценке пользователей)_ числа со значениями после точки, то был изменён тип с object на float;
#
# _И в user_score, и в critic_score_ было больше всего пропущенных данных, для более адекватной работы с данными все NaN значения я привела к маркеру __101__, который стал для меня индикатором того, что это отсутствие значения. Заполнять такое количество данных медианным значением я считаю не хорошей стратегией, потому что данные могут исказиться.
#
# В колонке _year_of_release (год выпуска)_ был изменён тип данных с float на int, потому что года это целые числа. Также, было __269 пропусков__. Просмотрев данные по двум колонкам _year_of_release и name_ я приняла решение, что заменю возможное количество пропусков по условию, которое сделает замену пропущенного года по имени игры (так как есть ситуации - есть название игры и есть год релиза, а есть название этой же игры, но нет года). Количество пропусков снизилось до - __146__ их я уже удалила (процент удалённых данных очень маленький и не повредит для последующей работы).
#
# В столбце _rating (рейтинг от организации ESRB)_ были заменены несколько строк со значением K-A (так как это устаревшее обозначение) на E, соответственно, первые обозначения необходимо заменить на вторые.
#
# Также был создан дополнительный столбик __rating_meaning__ с объяснением того, что именно обозначают буквы из рейтинга ESRB для более простого понимания будущих графиков и их анализа.
#
# В колонках _rating - 40% и rating_meaning - 40%_ оставила данные с пропусками, потому что в остальных столбцах есть информация в соответствующих строках. Также все пропуски я заменила на rp, потому что у них нет рейтинга.
#
# Также была создана колонка __sales_grouped__ с суммой продаж по всем регионам на каждую игру.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Отлично! Приступим к исследовательскому анализу.
# </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Посмотреть, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
print(games.year_of_release.unique())
# Out:
# <IntegerArray>
# [2006, 1985, 2008, 2009, 1996, 1989, 1984, 2005, 1999, 2007, 2010, 2013, 2004,
#  1990, 1988, 2002, 2001, 2011, 1998, 2015, 2012, 2014, 1992, 1997, 1993, 1994,
#  1982, 2016, 2003, 1986, 2000, 1995, 1991, 1981, 1987, 1980, 1983]
# Length: 37, dtype: Int64

# %%
# Создам функцию для отображения данных дописала функцию
def create_a_bar(groupby_column, func, y='name'):
    sns.set_style('darkgrid')
    to_plot = games.groupby(groupby_column)[y]
    if func == 'count':
        calculate = to_plot.count()
        figsize = (15,5)
        plot = calculate.plot(kind='bar', y=y, figsize=figsize, ec='black', color='lightgreen')

# %%
create_a_bar('year_of_release', 'count')
plt.title('Сколько игр выпускалось в разные годы')
plt.xlabel('Годы выпуска')
plt.ylabel('Выпуск игр');

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Обрати, пожалуйста, внимание на выбросы в районе нуля из-за заглушки. Здесь либо ставить ифльтр, либо не заполнять пропуски, а удалить.
#
# Также не забывай, пожалуйста прафилльно оформлять графики, а именно: давать им названия и подписи осям.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
# Я чёт не понимаю в куда мне прописать фильтр Ж0 <b>UPD</b> Поняла, переделала, но именно в годах всех я не поняла.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# В годах нам заглушки по-сути не нужна, если мы удалили пропуски. Но если пропуски заполнили заглушкой, то тогда её необходимо фильтровать, дабы она не искажала результаты.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.2</b>
#
# Удалила. И до меня дошло наконец-то что и почему не так работало!
# </div>

# %% [markdown]
# Меньше всего данных в период с 1980 по 2000 годы. Но тут ничего удивительного, т.к. сначала были аркадные игры (где-то с 70х годов прошлого века), потом потихоньку развивались технологии и к 90м года появились CD-ROMы, операционки, на основе GUI (такие как AmigaOS, Microsoft Windows и Mac OS), появление и широкое распространение 3D графики и появление интернета. Благодаря развитию технологий и способов передачи данных (тоже появление операционок для Эппл и андроидов) распространение игр и их использование становилось проще.
#
# В 2008-2009 годах можно отметить самый пик развития игр. После этого идёт достаточно резкий спад, который скорее всего обусловлен сегментом мобильных игр, которые начали развиваться и вливаться в игровую индустрию.
#
# __Предполагаю, что данные за все года не так важны будут для выявления закономерности успешности игр, так как задача сделать прогноз на 2017 год.__
#
# В динамично меняющейся индустрии компьютерных игр нужно учитывать параметр того, что тренды изживают сами себя. Соответственно интервал для прогнозирования успешных игр на 2017 год лучше сделать по сроку не больше 5 лет, соответственно нужно взять данные после пика и не раньше 5 лет до 2016 года. __Это 2014-2016гг. По ним уже и буду работать.__

# %% [markdown]
# ### Работа с платформами и поиск ответов на вопросы по лучшей из представленных

# %% [markdown]
# #### Выбрать платформы с наибольшими суммарными продажами и построить распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?

# %%
top_5_find = games.query('year_of_release >= 2014')
top_5_find.head(5)
(
    top_5_find.pivot_table(index='platform', values='sales_grouped', aggfunc='sum')
    .sort_values('sales_grouped', ascending = False)
    .plot(y='sales_grouped', kind='barh', figsize=(16, 8), title='Наибольшее по сумме продаж',
          grid=True, ec='black', color='lightgreen', alpha=0.5, legend=False)
    .set(xlabel='Суммы в млн', ylabel='Платформы')
)
plt.show();

# %% [markdown]
# Распределила платформы на группы по графику.
#
# _Группа 1_ Самые высокие показатели у __ps4__
#
# Далее идёт ряд платформ, у которых идёт большое отставание.
#
# _Группа 2_ __xone, 3ds, ps3__.
#
# _Группа 3_ __x360__.
#
# _Группа 3_ Самые маленькие у __pc, wii, wiiu, psv__.
#
# _Группа 4_ Близкие к нулю показатели, но всё-таки "видимые" у __psp__

# %% [markdown]
# #### Какие платформы лидируют по продажам, растут или падают? Выбрать несколько потенциально прибыльных платформ

# %% [markdown]
# __Какие платформы выбрать?__ Просмотрев таблицу, можно сделать вывод, что нужно взять платформы из Группы 1, Группы 2 и Группы 3 (т.е. 5 платформ).
#
# Значит распределение по годам буду строить именно по этим трём группам, то есть по платформам значение суммы которых от 100 и выше. Что мне надо - свести всё вместе, где указать ежегодный объём продаж, отфильтровать значения от 2011 года и выше и, собственно всё вывести на экран.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Если это наш актуальный период, то для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватим уже отжившие тренды. Но и очень короткий период не подходит для прогнозирования, так что надо выбирать золотую середину (но не менее 2-х полных лет и не более 5 лет). Так, как все расчеты ниже необходимо использовать с актуальным периодом, то не забудь, пожалуйста перепроверить их и выводы после корректировки.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
#
# Я тут психанула и сделала проще, а то что-то сама себя в коде запутала с этими мёрджами. Тут же проще всё можно сделать. К тому же я чёт тупанула, а в ТЗ было написано про топ5 платформ, поэтому буду делать топ5 платформ.
#
# Сначала отфильтрую дату по нужным годам, т.е. от 2011 и выше, потом выведу платформы, которые лидируют.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# ✍
# Только ты не внимательно прочитала мою подсказку :( Минимальный порог - 5лет, а с 2011 это 6 лет. Самый идеальный вариант это с 2014г.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.2</b>
#
# Не, ну тупить - это святое (нет) Ж).
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 👍
# Тяжело в учении - легко на работе :)
# </div>

# %%
ps3 = games.query('platform == "ps3"').pivot_table(index='year_of_release', values='sales_grouped', aggfunc='sum')
x360 = games.query('platform == "x360"').pivot_table(index='year_of_release', values='sales_grouped', aggfunc='sum')
ps4 = games.query('platform == "ps4"').pivot_table(index='year_of_release', values='sales_grouped', aggfunc='sum')
ds3 = games.query('platform == "3ds"').pivot_table(index='year_of_release', values='sales_grouped', aggfunc='sum')
xone = games.query('platform == "xone"').pivot_table(index='year_of_release', values='sales_grouped', aggfunc='sum')

top_5 = (
    ps3.merge(x360, how='outer', on='year_of_release')
    .merge(ps4, how='outer', on='year_of_release')
    .merge(ds3, how='outer', on='year_of_release')
    .merge(xone, how='outer', on='year_of_release')
)

# Ещё переименую названия столбиков, чтобы было всё удобнее
top_5.set_axis(['ps3', 'x360', 'ps4', '3ds', 'xone'], axis='columns', inplace=True)

# %%
top_5_2011 = top_5.query('year_of_release >= 2014')

top_5_2011.plot(stacked=True, figsize=(16, 9), title='Объём продаж с 2014 по 2016 по 5 платформам',
                grid=True).set(xlabel='Релизный год', ylabel='Объём продаж');

# %% [markdown]
# В основном, пик продаж сходится примерно к 5 году существования консоли на рынке (оно и понятно, примерно за это время рынок начинают массово выпускаться новые игры к ним или ребуты игр на них с консолей прошлого поколения). Также, можно отметить, что у всех платформ к 2016 году виден резкий спад, близящийся к нулю.
#
# Что по продажам?
#
# __Xbox One -__ самая продаваемая из всех. Серебро у __Nintendo 3DS__, а бронза у __PlayStation 4__.
#
# Что по годам? По графикам можно отметить, что в основном платформы "живут" около 10 лет. Мне стало интересно так ли это, поэтому я загуглила все платформы.
#
# __NB__: год, который я указываю началом существования консоли означает дату релиза в первой стране (т.е. с первой страны, где она стартовала).
#
# __NB__: год, который я указываю окончанием существования консоли означает прекращение её поддержки.
#
# __Xbox One -__ просуществовала с 2013 по 2020 год(https://ru.wikipedia.org/wiki/Xbox_One) = 7 лет.
#
# __Nintendo 3DS -__ просуществовала с 2011 по 2020 год (https://ru.wikipedia.org/wiki/Nintendo_3DS) = 9 лет.
#
# __PlayStation 4 -__ просуществовала с 2013 по 2021 год (https://ru.wikipedia.org/wiki/PlayStation_4) = 8 лет.
#
# __Xbox 360 -__ просуществовала с 2005 по 2016 год (https://ru.wikipedia.org/wiki/Xbox_360) = 11 лет.
#
# __Playstation 3 -__ просуществовала с 2006 по 2017 год (https://ru.wikipedia.org/wiki/PlayStation_3) = 11 лет.
#
#
# Да, всё сошлось - платформы живут около 10 лет.
# Если говорить конкретно про топ 5 платформ, то эта продолжительность жизни чуть больше 9 лет (9.2, если быть точнее). Есть долгожители вроде второй плойки и есть мало просуществовавшие как нинтендо ви.
#
# К "окончанию жизненного цикла" консолей спадают и продажи, думаю, это обусловлено тем, что новые консоли продолжают выпускать и они с более крутым железом, соответственно у старых версий конкуретноспособность снижается из-за устарелости.

# %% [markdown]
# #### Построить боксплот по глобальным продажам игр в разбивке по платформам. Описать результат.

# %% [markdown]
# Следуя логике предыдущих пунктов я могу подытожить, что все данные будет нерелевантно использовать (потому что некоторые платформы вообще в тот же 2000 год ещё не вышли, а в 2014 году существовали все и он ближе всего для мерила нужного периода) и можно ограничиться средним по палате и взять года с 2014 по 2016 и работать уже непосредственно с ними, потому что в этом временном отрезке представлены все нужные консоли (при этом я помню, что данные за 2016 год неполные).
#
# Что мне надо - убрать выбросы (потому что я раньше их не трогала) разбросом в 1.5.

# %%
needed_period = games[games['year_of_release'] >= 2014]
top_5_list = ['ps3', 'x360', 'ps4', '3ds', 'xone']
games_top_5 = needed_period[needed_period['platform'].isin(['ps3', 'x360', 'ps4', '3ds', 'xone'])]
games_top_5 = games_top_5[games_top_5['sales_grouped'] < 1.5]
games_top_5['sales_grouped'].describe() #ура! работает и проще делать Ж)
# Out:
# count    1040.000000
# mean        0.251317
# std         0.314114
# min         0.010000
# 25%         0.040000
# 50%         0.110000
# 75%         0.340000
# max         1.490000
# Name: sales_grouped, dtype: float64

# %%
(
    games_top_5
    .pivot_table(index='platform', values='sales_grouped')
    .sort_values('sales_grouped', ascending = False)
    .plot(y='sales_grouped', kind='barh', figsize=(15, 8), title='Суммарный объём продаж по платформам',
          grid=True, ec='black', color='lightgreen', legend=False)
    .set(xlabel='Объём продаж в млн', ylabel='Платформы')
)
plt.show();

# %% [markdown]
# Теперь строю боксплот.

# %%
plt.figure(figsize=(16, 9))
sns.boxplot(data=games_top_5, x='platform', y='sales_grouped', notch=True)
plt.title('Разбивка по топовым 5 платформам')
plt.xlabel('Платформа')
plt.ylabel('Глобальные продажи в млн')
plt.show()

# %% [markdown]
# Картина отличается от предыдущих графиков. У каждой платформы медиана разная, но тенденцию движения к нижнему квартилю можно обнаружить у каждой. Выбросы у всех платформ сосредоточились выше максимального значения. В общем можно отметить, что меньше всего разбросов значений у __3ds__ и __ps3__, у остальных платформ разброс достаточно велик.
#
# Также, заметно, что у __xone__ медиана ближе всего к 2млн., а вот у остальных платформ - ниже.
#
# Если посмотреть на 3ds, ps4, x360 и ps3 она больше близиться от 0.1, т.е. тяготеет к 1млн.
#
# Самое высокое значение у __Xbox one__ и близится к 4,5 миллионам(немного юольше, чем у x360). Её и возьму для следующей проверки.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Диаграмма построена верно, но после определения корректного актуального периода эти данные могут измениться.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
# И они нехило так поменялись, ты был прав!
# </div>

# %% [markdown]
# #### Посмотреть, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Построить диаграмму рассеяния и посчитать корреляцию между отзывами и продажами. Сформулировать выводы.

# %%
game_filter_xone_1 = games_top_5.query('platform == "xone" and user_score < 101 and critic_score < 101')
game_filter_xone_1.plot(kind='scatter', x='user_score', y='sales_grouped', figsize=(10, 6), color='green')
plt.title('Xbox one')
plt.xlabel('Оценки игроков')
plt.ylabel('Глобальные продажи в млн.')
plt.show()
print('Корреляция Пирсона по оценкам игроков и продажам:', (game_filter_xone_1['user_score'].corr(game_filter_xone_1['sales_grouped'])))
# Out:
# Корреляция Пирсона по оценкам игроков и продажам: 0.0699334124318835

# %%
game_filter_xone_2 = games_top_5.query('platform == "xone" and user_score < 101 and critic_score < 101')
game_filter_xone_2.plot(kind='scatter', x='critic_score', y='sales_grouped', figsize=(10, 6), color='green')
plt.title('Xbox one')
plt.xlabel('Оценки критиков')
plt.ylabel('Глобальные продажи в млн.')
plt.show()
print('Корреляция Пирсона по оценкам критиков и продажам:', (game_filter_xone_2['critic_score'].corr(game_filter_xone_2['sales_grouped'])))
# Out:
# Корреляция Пирсона по оценкам критиков и продажам: 0.4392458917422066

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# И снова наши выбросы из-за заглушки.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
#
# Вау! Как же всё поменялось!
#
# Ты - лучший!
#
# Спасибо, что обратил моё внимание на фильтрацию!
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Как бы сказал Киану Ривз: "Это ты лучшая!"
# </div>

# %% [markdown]
# Чем больше положительных отзывов - тем больше прибыли? Судя по графикам можно сделать выводы:
#
# __Соотношение оценок игроков и продаж__
#
# Есть отдельные негативные отзывы, которые совсем не повлияли на приобретение - "1", "2", "3" и "4". И это имеет смысл - вспомнить тот же Kengo, Legend of the 9 (задумка хорошая, но очень однотипная по каждой миссии) и пройти некоторое количество часов, но, при этом остаться недовольными - потому что там геймплей оставляет желать лучшего. И это не одна такая эксклюзивная игра для этой платформы. Игроки спокойно могли поставить и низкую оценку игре. В "3" и "4" - есть отдельные игры, которые превысили 4 млн, но не смогли пробить потолок в 8.
#
# Единичные случаи, превысившие 6 млн у оценок в "9", но их меньшинство.
#
# Большинство положительных отзывов расположилось на оценках "5", "6", "7" и "8". Также, как и в предыдущих, есть отдельные игры, которые вышли за предел в 8млн, но их меньше, по-сравнению с основной массой, практически единичные случаи.
#
# Скорее всего, такая картина связана с возможностями железа и реализацией игр на консоль.
#
# __Соотношение оценок критиков и продаж__
#
# Есть отдельный сегмент, где критики плохо оценили игры от "1" до "50" (скорее всего это что-то наподобие приведённых примеров в оценке игроков), необходимо учесть, что такие игры не вышли за границу в 4 млн.
#
# Средний показатель оценок критиков и прибыли, в независимости от оценки, находится в пределе от 1 до 8 млн (но не выше).
#
# Также нужно отметить, что высокие оценки критиков "помогли" получить прибыль выше 10млн. единицам (доходя даже до 14млн!), но немного большему числу, нежели оценки игроков и такие положительные отзывы оссредоточились на оценках от "70" до "100".
#
# Округлённо, разница между корреляциями отзывов критиков и игроков составляет - 0.37. Влияют ли положительные отзывы нв повышение прибыли? Думаю, что не сильно.

# %% [markdown]
# ### Работа с платформами и поиск ответов на вопросы по остальным платформам

# %% [markdown]
# #### Соотнести выводы с продажами игр на других платформах.

# %% [markdown]
# Сначала отделю другие платформы от топовой шестёрки

# %%
other_ranged_games = games.query('platform not in @games_top_5')
other_ranged_games.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                wii sports      wii             2006        sports     41.36
# 1         super mario bros.      nes             1985      platform     29.08
# 2            mario kart wii      wii             2008        racing     15.68
# 3         wii sports resort      wii             2009        sports     15.61
# 4  pokemon red/pokemon blue       gb             1996  role-playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      e
# 1      3.58      6.81         0.77         101.0       101.0     rp
# 2     12.76      3.79         3.29          82.0         8.0      e
# 3     10.93      3.28         2.95          80.0         8.0      e
# 4      8.89     10.22         1.00         101.0       101.0     rp
#
#   rating_meaning  sales_grouped
# 0       Для всех          82.54
# ...

# %%
other_ranged_games_users = other_ranged_games.query('user_score < 101 and critic_score < 101')
other_ranged_games_users.head()
# Out:
#                     name platform  year_of_release     genre  na_sales  \
# 0             wii sports      wii             2006    sports     41.36
# 2         mario kart wii      wii             2008    racing     15.68
# 3      wii sports resort      wii             2009    sports     15.61
# 6  new super mario bros.       ds             2006  platform     11.28
# 7               wii play      wii             2006      misc     13.96
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      e
# 2     12.76      3.79         3.29          82.0         8.0      e
# 3     10.93      3.28         2.95          80.0         8.0      e
# 6      9.14      6.50         2.88          89.0         8.0      e
# 7      9.18      2.93         2.84          58.0         6.0      e
#
#   rating_meaning  sales_grouped
# 0       Для всех          82.54
# 2       Для всех          35.52
# ...

# %%
other_ranged_games_critics = other_ranged_games.query('user_score < 101 and critic_score < 101')
other_ranged_games_critics.head()
# Out:
#                     name platform  year_of_release     genre  na_sales  \
# 0             wii sports      wii             2006    sports     41.36
# 2         mario kart wii      wii             2008    racing     15.68
# 3      wii sports resort      wii             2009    sports     15.61
# 6  new super mario bros.       ds             2006  platform     11.28
# 7               wii play      wii             2006      misc     13.96
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      e
# 2     12.76      3.79         3.29          82.0         8.0      e
# 3     10.93      3.28         2.95          80.0         8.0      e
# 6      9.14      6.50         2.88          89.0         8.0      e
# 7      9.18      2.93         2.84          58.0         6.0      e
#
#   rating_meaning  sales_grouped
# 0       Для всех          82.54
# 2       Для всех          35.52
# ...

# %% [markdown]
# Смотрю что по продажам и рейтингу игроков.

# %%
other_ranged_games_users.plot(kind='scatter', x='user_score', y='sales_grouped', figsize=(10, 6), color='green')
plt.title('Игры, не вошедшие в топ 5')
plt.xlabel('Оценки игроков')
plt.ylabel('Глобальные продажи в млн.')
plt.show()
print('Корреляция Пирсона по оценкам игроков и продажам:', (other_ranged_games_users['user_score'].corr(other_ranged_games_users['sales_grouped'])))
# Out:
# Корреляция Пирсона по оценкам игроков и продажам: 0.08629711965375085

# %%
other_ranged_games_critics.plot(kind='scatter', x='critic_score', y='sales_grouped', figsize=(10, 6), color='green')
plt.title('Игры, не вошедшие в топ 5')
plt.xlabel('Оценки критиков')
plt.ylabel('Глобальные продажи в млн.')
plt.show()
print('Корреляция Пирсона по оценкам критиков и продажам:', (other_ranged_games_critics['critic_score'].corr(other_ranged_games_critics['sales_grouped'])))
# Out:
# Корреляция Пирсона по оценкам критиков и продажам: 0.23715572585617842

# %% [markdown]
# Чем больше положительных отзывов - тем больше прибыли? Может в остальных платформах будет другая ситуация? В этих графиках картина сложилась таким образом:
#
# __Соотношение оценок игроков и продаж__
#
# Большинство оценок игроков не превышают 20 млн. - 0, 1, 2, 3, 4 и 5.
#
# Оценки в 6, 7, 8 и 9 - не превышают отметку в 30 млн., есть единичные игры, получившие прибыль выше 40 и 80млн.
#
# __Соотношение оценок критиков и продаж__
#
# Тут картина совпадает с соотношением оценок игроков и продаж, т.е. в большинстве случаев даже самый высокий балл от критиков не гарантирует большое количество продаж.
#
# Округлённо, разница между корреляциями отзывов критиков и игроков составляет - 0.15 (небольшая). Влияют ли положительные отзывы на повышение прибыли? Думаю, что не сильно.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Верно. Оценка критиков имеет слабое влияние на продажи, оценка пользователей на продажи не влияет.
# </div>

# %% [markdown]
# #### Посмотреть на общее распределение игр по жанрам.

# %% [markdown]
# Что мне надо - фильтр от 2014 года по 2016. Нужно посчитать количество продаж и вычислить медиану (потому что на неё меньше влияют выбросы, нежели на среднее арифметическое) общую сумму по имени и всё это сделать по жанрам.

# %%
names_of_genres = games['genre']
print(names_of_genres.sort_values().unique())
# Out:
# ['action' 'adventure' 'fighting' 'misc' 'platform' 'puzzle' 'racing'
#  'role-playing' 'shooter' 'simulation' 'sports' 'strategy']

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# ✍
# А вот здесь наш код упал с ошибкой :( Не торопись, будь внимательна. Не забывай перед отправкой проекта и вообще переодически перезапускать ядро тетрадки. Сделать это можно так: Kernel -> Restart And Kernel All. Так мы убедимся, что все ячейки отрабатывают корректно. Буду ждать твою работу :)
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.2</b>
#
# Потому что я подумала - о, прикольно, надо попробовать код в проекте и забыла его попробовать Ж)
#
# Эт про то что подумала о том, что сделала, но не сделала (лошара, блин).
#
# Я его попробовала, но такое, поэтому убрала.
#
# Ну и да, надо не торопиться и через кернел буду теперь перепроверять, чтобы всё точно работало)
#
# Я просто хотела посмотреть как жанры будут выглядеть боксплотом (всегда иду через энное место в постигании дзена, зато разобралась и почти довольна боксплотом.
# </div>

# %%
names_of_genres1 = games_top_5.pivot_table(index='genre', values='sales_grouped', aggfunc='median').sort_values(
    by='sales_grouped', ascending=False).reset_index().rename_axis(None, axis=1)
names_of_genres1.style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_3ac46_row0_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_3ac46_row1_col1{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_3ac46_row2_col1{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_3ac46_row3_col1{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_3ac46_row4_col1{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_3ac46_row5_col1,#T_3ac46_row6_col1{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_3ac46_row7_col1{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_3ac46_row8_col1{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_3ac46_row9_col1,#T_3ac46_row10_col1,#T_3ac46_row11_col1{
#             background-color:  #3b4cc0;
# ...

# %%
ranged_games0 = games.query('year_of_release > 2014 and user_score < 101 and critic_score < 101')
plt.figure(figsize=(15,9))
plt.title('Распределение игр по жанрам ',fontsize=15)
sns.barplot(data=ranged_games0, x='genre', y='sales_grouped')
plt.xlabel('Жанры игр',fontsize=12)
plt.ylabel('Глобальные продажи в млн',fontsize=12)
plt.show();

# %%
def cm_to_inch(value):
    return value/2.54
plt.figure(figsize=(cm_to_inch(45),cm_to_inch(25)))
sns.boxplot(data=ranged_games0, x='sales_grouped', y='genre', notch=True)
plt.title('Разбивка по жанрам')
plt.xlabel('Глобальные продажи в млн')
plt.ylabel('Жанры')
plt.show();

# %% [markdown]
# __Что можно сказать о самых прибыльных жанрах?__
#
# Самым прибыльным жанром является shooter.
#
# Второе место у sports.
#
# Третье у fighting.
#
# Самыми непопулярными играми оказались стратегии, пазлы и miscelaneous(которые не подходят под остальные категории) - скорее всего из-за того, что в таких играх происходит меньше "движения" и они, по большей части не особо финансируются.
#
# Тут ещё можно добавить, что всё зависит от себестоимости игр - некоторые игры бывают очень дорогими и, соответственно, у них будет и ценник (как, например у экшенов, файтеров и шутеров), а некоторые игры - не самые дорогие в производстве (как например пазлы - про стратегии такое не совсем могу сказать - вспомнить тот же Age of Wonders и всё, что с ним связано).
#
# Ролевые игры - тоже собирают очень неплохо, но по сравнению с первыми тремя не дотягивают до их уровня.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Общие продажи - плохая метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого стоит рассмотреть средние или медианные продажи. Лучше всего нам это покажет boxplot.
#
# И здесь нам также необходим актуальный период.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
#
# У меня что-то мозга не хватило, чтобы сделать боксплот(((
#
# Каким путём его можно сделать? В смысле - в каком направлении мне думать?
#
# Маленько поменяла вывод 3.4.
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.2</b>
#
# Всё, мозга хватило.
#
# Выглядит неплохо, но я ещё не до конца разобралась с тем как масштабировать вернее боксплоты.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 👍
# Еще так можно :)
# </div>

# %%
#Код ревьюера
import matplotlib.pyplot as plt

plt.figure(figsize=(13, 8))
(sns.boxplot(data = games, y = 'sales_grouped', x='genre')
    .set(title = 'Продажи по жанрам', xlabel = 'Платформы', ylabel = 'Общие продажи', ylim=(0, 3)))

plt.show()

# %% [markdown]
# ### Вывод:

# %% [markdown]
# __Важны ли данные за все периоды?__
#
# Как я выяснила - для более детального и правильного разбора не важны все годы существования игр, а необходимо учитывать более близкие.
#
# ______ __Работа с платформами и поиск ответов на вопросы по лучшей из представленных__ ______
#
# __За какой характерный срок появляются новые и исчезают старые платформы?__
#
# В среднем это 9-10 лет.
#
# __Какие платформы лидируют по продажам, растут или падают?__
#
# Из всех групп, на которые я разбила платформы, я выбрала две самые прибыльные - Группа 1 ps4, Группа 2 xone, 3ds, ps3 и Группа 3 x360.
#
# __Боксплот по глобальным продажам__
#
# Картина отличается от предыдущих графиков. У каждой платформы медиана разная, но тенденцию движения к нижнему квартилю можно обнаружить у каждой. Выбросы у всех платформ сосредоточились выше максимального значения. В общем можно отметить, что меньше всего разбросов значений у 3ds и ps3, у остальных платформ разброс достаточно велик.
#
# Также, заметно, что у xone медиана ближе всего к 2млн., а вот у остальных платформ - ниже.
#
# Если посмотреть на 3ds, ps4, x360 и ps3 она больше близиться от 0.1, т.е. тяготеет к 1млн.
#
# Самое высокое значение у Xbox one и близится к 4,5 миллионам(немного больше, чем у x360).
#
# __Как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков.__
#
# Чем больше положительных отзывов - тем больше прибыли? Может в остальных платформах будет другая ситуация? В этих графиках картина сложилась таким образом:
#
# __Соотношение оценок игроков и продаж__
#
# Есть отдельные негативные отзывы, которые совсем не повлияли на приобретение - "1", "2", "3" и "4". И это имеет смысл - вспомнить тот же Kengo, Legend of the 9 (задумка хорошая, но очень однотипная по каждой миссии) и пройти некоторое количество часов, но, при этом остаться недовольными - потому что там геймплей оставляет желать лучшего. И это не одна такая эксклюзивная игра для этой платформы. Игроки спокойно могли поставить и низкую оценку игре. В "3" и "4" - есть отдельные игры, которые превысили 4 млн, но не смогли пробить потолок в 8.
#
# Единичные случаи, превысившие 6 млн у оценок в "9", но их меньшинство.
#
# Большинство положительных отзывов расположилось на оценках "5", "6", "7" и "8". Также, как и в предыдущих, есть отдельные игры, которые вышли за предел в 8млн, но их меньше, по-сравнению с основной массой, практически единичные случаи.
#
# Скорее всего, такая картина связана с возможностями железа и реализацией игр на консоль.
#
# __Соотношение оценок критиков и продаж__
#
# Есть отдельный сегмент, где критики плохо оценили игры от "1" до "50" (скорее всего это что-то наподобие приведённых примеров в оценке игроков), необходимо учесть, что такие игры не вышли за границу в 4 млн.
#
# Средний показатель оценок критиков и прибыли, в независимости от оценки, находится в пределе от 1 до 8 млн (но не выше).
#
# Также нужно отметить, что высокие оценки критиков "помогли" получить прибыль выше 10млн. единицам (доходя даже до 14млн!), но немного большему числу, нежели оценки игроков и такие положительные отзывы оссредоточились на оценках от "70" до "100".
#
# Округлённо, разница между корреляциями отзывов критиков и игроков составляет - 0.37. Влияют ли положительные отзывы нв повышение прибыли? Думаю, что не сильно.
#
#
# ______ __Работа с платформами и поиск ответов на вопросы по остальным платформам__ ______
#
# __Выводы с продажами игр на других платформах__
#
# __Соотношение оценок игроков и продаж__
#
# Большинство оценок игроков не превышают 20 млн. - 0, 1, 2, 3, 4 и 5.
#
# Оценки в 6, 7, 8 и 9 - не превышают отметку в 30 млн., есть единичные игры, получившие прибыль выше 40 и 80млн.
#
# __Соотношение оценок критиков и продаж__
#
# Самым прибыльным жанром является shooter. Второе место у sports. Третье у fighting.
#
# Самыми непопулярными играми оказались стратегии, пазлы и miscelaneous(которые не подходят под остальные категории) - скорее всего из-за того, что в таких играх происходит меньше "движения" и они, по большей части не особо финансируются.
#
# Тут ещё можно добавить, что всё зависит от себестоимости игр - некоторые игры бывают очень дорогими и, соответственно, у них будет и ценник (как, например у экшенов, файтеров и шутеров), а некоторые игры - не самые дорогие в производстве (как например пазлы - про стратегии такое не совсем могу сказать - вспомнить тот же Age of Wonders и всё, что с ним связано).
#
# Ролевые игры - тоже собирают очень неплохо, но по сравнению с первыми тремя не дотягивают до их уровня.
#
# __Общее распределение игр по жанрам__
#
# По подсчёту, самыми прибыльными игровыми жанрами оказались:
#
#                 Игровой жанр  Объём продаж в млн
#
#                 shooter       0.350000
#                 sports        0.155000
#                 fighting      0.130000
#                 role-playing  0.120000
#                 racing        0.115000
#
# Самыми неприбыльными:
#
#                Игровой жанр   Объём продаж в млн
#
#                 adventure     0.060000
#                 puzzle        0.060000
#                 strategy      0.060000

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Молодец, что не забываешь писать промежуточные выводы и сохраняешь структуру проекта.
# </div>

# %% [markdown]
# ## Портреты пользователей каждого региона (na, eu, jp)

# %% [markdown]
# Для каждого пользователя из na, eu и jp необходимо определить:
#
#         - самые популярные платформы (топ-5). Описать различия в долях продаж.
#
#         - самые популярные жанры (топ-5). Пояснить разницу.
#
#         - влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
# Попробую сделать круговую диаграмму, чтобы было наглядно и сразу всё понятно, помню, что мне необходим обозначенный выше временной отрезок, т.е. 2006 год, также надо посчитать процент продаж от общего объёма на рынке, жанры по популярности и рейтинг.

# %% [markdown]
# ### Северная Америка

# %%
# все платформы по региону
games_na_eu_jp = games.query(
    'year_of_release >= 2014 and na_sales > 0 and jp_sales > 0 and eu_sales > 0 and user_score < 101 and critic_score < 101'
)

# сводные таблицы за нужный период
def users_na_eu_jp(row, title):
    temp = games_na_eu_jp
    fig, axes = plt.subplots(1, 3, figsize=(20, 9))
    for pivot, ax in zip(list(['platform','genre','rating']),axes):
        ppivot = games_na_eu_jp.pivot_table(index=pivot, values=row, aggfunc='sum'
                  ).sort_values(by=row, ascending=False
                               ).reset_index().rename_axis(None, axis=1)
        display(ppivot) 
        sns.color_palette('coolwarm', n_colors=10)
        sns.barplot(data=ppivot, x=row, y=pivot, ax=ax)
        fig.suptitle(title, fontsize=15)      
plt.show()
sns.set()

# %%
users_na_eu_jp('na_sales', 'Северная Америка. Топ 5 платформ, жанров и рейтингов')
# Out:
#   platform  na_sales
# 0      ps4     57.76
# 1     xone     18.65
# 2     wiiu     12.55
# 3      3ds      7.09
# 4      ps3      2.51
# 5     x360      1.81
# 6      psv      1.28
#            genre  na_sales
# 0        shooter     33.07
# 1         action     29.50
# 2   role-playing     12.49
# 3         sports      9.39
# 4         racing      5.67
# 5       platform      4.66
# 6           misc      2.24
# 7       fighting      2.16
# 8      adventure      1.23
# 9     simulation      0.57
# 10        puzzle      0.53
# 11      strategy      0.14
#   rating  na_sales
# 0      m     51.60
# 1      t     21.21
# 2      e     18.90
# 3   e10+      9.81
# 4     rp      0.13

# %% [markdown]
# __Топ 5 платформ в Северной Америке:__
#
# ps4     57.76
#
# xone    18.65
#
# wiiu    12.55
#
# 3ds     7.09
#
# ps      32.51
#
# __Хуже всего у__
#
# x360    1.81
#
# psv     1.28
#
# __Топ 5 жанров в Северной Америке:__
#
# shooter       33.07
#
# action        29.50
#
# role-playing  12.49
#
# sports        9.39
#
# racing        5.67
#
# __Хуже всего у__
#
# simulation  0.57
#
# puzzle      0.53
#
# strategy    0.14
#
# __По влиянию рейтинга ESRB на продажи в Северной Америке:__
#
# m(с 17 лет)     51.60
#
# t(с 13 лет)     21.21
#
# e(для всех)     18.90
#
# e10+(с 10 лет)  9.81
#
# __Хуже всего у__
#
# rp(нет категории)  0.13

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Обрати внимание, что секотрная диаграмма на фоне стольких категорий становится не очень информативна. Здесь больше бы подошел столбчатый график.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
#
# Попробую сделать как надо)
#
# Полнедели, но выстрадала я функцию)
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Исходя из расчетов выводы верные, но после корректировки актуального периода скорей всего их нужно будет переписать.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.2</b>
#
# Да, ведь рейтинги тут совсем-по-другому распределилсь из-за другого периода. Магия.
# </div>

# %% [markdown]
# ### Европа

# %%
users_na_eu_jp('eu_sales', 'Европа. Топ 5 платформ, жанров и рейтингов')
# Out:
#   platform  eu_sales
# 0      ps4     87.41
# 1     xone     11.09
# 2     wiiu      8.97
# 3      3ds      4.80
# 4      ps3      2.98
# 5      psv      0.77
# 6     x360      0.71
#            genre  eu_sales
# 0         action     34.68
# 1        shooter     31.62
# 2         sports     20.23
# 3   role-playing     11.23
# 4         racing      8.14
# 5       platform      4.04
# 6       fighting      1.93
# 7      adventure      1.76
# 8           misc      1.49
# 9     simulation      1.18
# 10        puzzle      0.38
# 11      strategy      0.05
#   rating  eu_sales
# 0      m     58.95
# 1      e     31.99
# 2      t     18.53
# 3   e10+      6.99
# 4     rp      0.27

# %% [markdown]
# __Топ 5 платформ в Европе:__
#
# ps4     87.41
#
# xone    11.09
#
# wiiu    8.97
#
# 3ds     4.80
#
# ps3     2.98
#
# __Хуже всего у__
#
# x360    0.71
#
# __Топ 5 жанров в Европе:__
#
# action        34.68
#
# shooter       31.62
#
# sports        20.23
#
# role-playing  11.23
#
# racing        8.14
#
# __Хуже всего у__
#
# puzzle        0.38
#
# strategy      0.05
#
# __По влиянию рейтинга ESRB на продажи в Европе:__
#
# m(с 17 лет)        58.95
#
# e(для всех)        31.99
#
# t(с 13 лет)        18.53
#
# e10+(с 10 лет)     6.99
#
# __Хуже всего у__
#
# rp(нет категории)  0.27

# %% [markdown]
# ### Япония

# %%
users_na_eu_jp('jp_sales', 'Япония. Топ 5 платформ, жанров и рейтингов')
# Out:
#   platform  jp_sales
# 0      3ds      8.81
# 1      ps4      7.66
# 2     wiiu      5.58
# 3      psv      1.97
# 4      ps3      1.51
# 5     xone      0.27
# 6     x360      0.04
#            genre  jp_sales
# 0   role-playing      7.43
# 1         action      5.84
# 2        shooter      3.66
# 3       platform      2.45
# 4         racing      1.49
# 5     simulation      1.46
# 6           misc      1.26
# 7         sports      0.99
# 8       fighting      0.90
# 9         puzzle      0.19
# 10     adventure      0.16
# 11      strategy      0.01
#   rating  jp_sales
# 0      t      8.04
# 1      e      8.03
# 2      m      6.18
# 3   e10+      3.51
# 4     rp      0.08

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Замечания:
#
# * Обрати внимание, что сводную мы делаем по games_na, а не по games_jp
#
# * Агрегирующую функцию по портретам стоит использовать sum, нам нужны суммарные продажи
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
#
# А это я просто проследила, но всё поправила.
#
# У меня ещё такой вопрос - как-то же можно в функцию запихнуть подсчёт процентов?
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 👍
# Попробуй посмотреть здесь: https://translated.turbopages.org/proxy_u/en-ru.ru.89abe778-64301c01-03e243db-74722d776562/https/stackoverflow.com/questions/5997987/is-there-an-operator-to-calculate-percentage-in-python
# </div>

# %% [markdown]
# __Топ 5 платформ в Японии:__
#
# 3ds    8.81
#
# ps4    7.66
#
# wiiu   5.58
#
# psv    1.97
#
# ps3    1.51
#
# __Хуже всего у__
#
# x360   0.04
#
# __Топ 5 жанров в Японии:__
#
# role-playing  7.43
#
# action        5.84
#
# shooter       3.66
#
# platform      2.45
#
# racing        1.49
#
# __Хуже всего у__
#
# strategy      0.01
#
# __По влиянию рейтинга ESRB на продажи в Японии:__
#
# t(с 13 лет)        8.04
#
# e(для всех)        8.03
#
# m(с 17 лет)        6.18
#
# e10+(с 10 лет)     3.51
#
# __Хуже всего у__
#
# rp(нет категории)  0.08

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Правильно, что мы при предобработке данных поставили заглушку на пропуски в рейтинге ESRB. Иначе игры без рейтинга оказались бы полностью исключенными из анализа. Продажи именно этих игр могут указать на ключевое различие в регионах.
# </div>

# %% [markdown]
# ### Вывод:

# %% [markdown]
# __Портреты пользователей по регионам:__
#
# ![image-4.png](attachment:image-4.png)
#
# __Северная Америка__
#
# В основном, пользователи Северной Америки предпочитают платформы ps4, xone, wiiu, 3ds, ps. Меньше всего они приобретают psv.
#
# Самые популярные жанры игр shooter, action, role-playing, sports, racing. Меньше всего игроков интересуют simulation, puzzle,
# strategy.
#
# Влияние рейтинга ESRB на продажи распределилось в на эти группы - m(с 17 лет), t(с 13 лет), e(для всех), e10+(с 10 лет), rp(нет категории).
#
# ![image-5.png](attachment:image-5.png)
#
# __Европа__
#
# Самыми популярными платформами для европейцев можно выделить - ps4, xone, wiiu, 3ds, ps3. Меньше всего покупают x360.
#
# Самые популярные жанры – action, shooter, sports, role-playing, racing. Меньше всего популярен strategy и puzzle.
#
# Влияние рейтинга ESRB на продажи - m(с 17 лет), e(для всех), t(с 13 лет), e10+(с 10 лет), rp(нет категории).
#
# ![image-6.png](attachment:image-6.png)
#
# __Япония__
#
# Самые популярные платформы в Японии – 3ds, ps4, wiiu, ps3, psv. Меньше всего покупают x360.
#
# Самые популярные жанры – role-playing, action, shooter, platform, racing. Меньше всего играют в strategy.
#
# Влияние рейтинга ESRB на продажи в Японии - e(для всех), t(с 13 лет), m(с 17 лет), e10+(с 10 лет), rp(нет категории).
#
# __Можно сделать такой вывод__
#
# Популярность платформ в каждом регионе своя, но:
#     - в каждом регионе в топ5 платформ присутсвуют - ps4, wiiu и 3ds.
#     - в Японии и Европе меньше всего покупают x360, а в Северной Америке - psv.
#
# Самые популярные жанры игр совпадают - это экшн, шутеры и ролевые игры (только в Европе ролевые игры обогнали спортивные). Остальные жанры в каждом регионе разнятся:
#
#     - в Сев.Америке и Европе список топ5 жанров совпадает - action, shooter, sports, role-playing, racing(скорее всего это обусловлено достаточной близостью как географической, так и культурной),
#
#     - в Японии - в топе отсутствуют спортивные игры, но вместо них - платформеры.
#
# Самые популярные игры:
#     - m(с 17 лет), e(для всех), t(с 13 лет), e10+(с 10 лет), rp(нет категории).
#
# Влияние рейтинга ESRB совпадает по всем пунктам, только разница в самом рейтинге региона.

# %% [markdown]
# ## Гипотезы

# %% [markdown]
# ### средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %% [markdown]
# Нужно сделать Series для платформ с оценками пользователей по нужному срезу лет и по нужным вопросам.
#
# Буду проверять гипотезы scipy.stats.ttest_ind()
#
# __Выбрать alpha__
#
# Есть стандартные уровни значимости 0,1; 0,05; 0,01; 0,001.
#
# Если объем выборки небольшой до 100 единиц, то можно вполне отвергнуть нулевую гипотезу при уровне значимости 0,05 или даже 0,1. При объеме выборки, измеряемой сотнями – от 100 до 1000, следует понизить уровень значимости хотя бы до 0,01. А при больших выборках, измеряемых тысячами наблюдений, уверенно отвергать нулевую гипотезу можно только при значимости меньшей 0,001. Соответственно нужно взять alpha = 0,05 для проверки гипотез.
#
# Соответственно, выбираю 0.05.

# %% [markdown]
# Два условия:
#
# - H0 средние рейтинги юзеров Xbox One и PC равны
#
# - H1 средние рейтинги юзеров Xbox One и PC не равны
#
# Из стобца platform мне нужны только xone и pc, а также определённые выше года с 2006 по 2016. Так как мне нужно использовать рейтинги юзеров - user_score.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Гипотезы сформулированы верно.
# </div>

# %%
for_xbx1 = games.query('platform == "xone" and year_of_release >= 2014 and user_score < 101 and critic_score < 101')['user_score']
for_pc = games.query('platform == "pc" and year_of_release >= 2014 and user_score < 101 and critic_score < 101')['user_score']
# средняя оценка по иксбоксу
print('Средняя оценка Xbox One =', for_xbx1.mean())
# средняя оценка по пк
print('Средняя оценка PC =', for_pc.mean())
# Out:
# Средняя оценка Xbox One = 6.225165562913907
# Средняя оценка PC = 5.860869565217391

# %%
alpha = 0.05 # критический уровень статистической значимости, если pvalue больше него, то гипотеза будет отвергнута
results = stats.ttest_ind(for_xbx1, for_pc, equal_var=False) # дисперсии не равны поэтому False
print('pvalue = ', results.pvalue)

if (results.pvalue < alpha):
    print('Нулевую гипотезу получилось отвергнуть')
else:
    print('Нулевую гипотезу не получилось отвергнуть')
# Out:
# pvalue =  0.05515706296559861
# Нулевую гипотезу не получилось отвергнуть

# %% [markdown]
# Тест показал, что:
# - pvalue =  0.05,
# - нулевая гипотеза подтверждена, следовательно нужно её принять - средние рейтинги юзеров Xbox One и PC равны.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Тест проведен корректно, но не по актуальному периоду, а прогноз мы строим именно по нему.
#
# Попадание или непопадание значения, посчитанного по выборке, в критический интервал - не повод считать, что наши гипотезы доказаны или нет. Иными словами, мы либо принимаем, либо не принимаем H₀(нулевую гипотезу). Данные лишь могут дать нам основания отвергнуть(или нет) H₀. В статистике гипотезы подтвердить невозможно.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
# Поправила)
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 👍
# Верно. Но повторю еще раз: в статистике гипотезы **подтвердить** невозможно. Это важный момент.
# </div>

# %% [markdown]
# ### средние пользовательские рейтинги жанров Action и Sports разные

# %% [markdown]
# Два условия:
#
# - H0 средние рейтинги юзеров Action и Sports одинаковые
#
# - H1 средние рейтинги юзеров Action и Sports разные
#
# Нужно сделать Series для игр с оценками пользователей по нужному срезу лет. Из стобца name мне нужны только action и sports, а также определённые выше года с 2006 по 2016. Так как мне нужно использовать - user_score.

# %%
for_action = games.query('genre == "action" and year_of_release >= 2014 and user_score < 101 and critic_score < 101')['user_score']
for_sports = games.query('genre == "sports" and year_of_release >= 2014 and user_score < 101 and critic_score < 101')['user_score']
# средняя оценка по экшнам
print('Средняя оценка Action =', for_action.mean())
# средняя оценка по спортивным играм
print('Средняя оценка Sports =', for_sports.mean())
# Out:
# Средняя оценка Action = 6.352422907488987
# Средняя оценка Sports = 5.289156626506024

# %%
alpha = 0.05 # критический уровень статистической значимости, если pvalue больше него, то гипотеза будет отвергнута
results = stats.ttest_ind(for_action, for_sports, equal_var=False)
print('pvalue=', results.pvalue)

if (results.pvalue < alpha):
    print('Нулевую гипотезу получилось отвергнуть')
else:
    print('Нулевую гипотезу не получилось отвергнуть')
# Out:
# pvalue= 6.966792262152512e-08
# Нулевую гипотезу получилось отвергнуть

# %% [markdown]
# Тест показал, что:
# - pvalue = 6.9667,
# - нулевую гипотезу получилось отвергнуть соответственно принимаю альтернативную - средние рейтинги юзеров Action и Sports разные.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Аналогично про актуальный период. Наны скорей всего из-за заглушек. пропуски и заглушки мы обязательно должны фильтровать перед проведением тестов.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
#
# Ура! Спасибо за совет! Всё получилось с фильтрами)
#
# Общий вывод поправила.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 👍
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# * Правильно, что для тестирования гипотез использован двусторонний t-тест Стьюдента.
#
#
#
# * Правильно, что показаны средние пользовательские рейтинги.  Это позволяет нам проверить не ошиблись ли мы, если они расходятся с тестом Стьюдента.
# </div>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <b> Из всего проведённого анализа, я выяснила следующее: </b>
#
#     Самые популярные жанры:
#
#         Северной Америки - shooter, action, role-playing, sports, racing;
#
#         Европы - action, shooter, sports, role-playing, racing;
#
#         Японии - role-playing, action, shooter, platform, racing.
#
#     Самые популярные платформы:
#
#         Северной Америки - ps4, xone, wiiu, 3ds, ps;
#
#         Европы - ps4, xone, wiiu, 3ds, ps3;
#
#         Японии - 3ds, ps4, wiiu, ps3, psv.
#
#
# <b> Из вышеизложенного следует, что во всех регионах : </b>
#
#         самыми популярными жанрами являются - shooter, action и role-playing;
#
#         самыми популярными платформами являются - разные, но в каждом регионе в топ5 платформ присутсвуют - ps4, ps3, wiiu и 3ds;
#
#         самые популярные топ 3 игры во всех регионах - m(с 17 лет), e(для всех), t(с 13 лет). В каждом регионе у них свой рейтинг, т.е. у каждой разное место в зависимости от региона.
#
#     Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании на последующий год (2017).
#
# <b> По оценкам пользователей и критиков: </b>
#
#     На продаваемость игр влияют больше оценки критиков нежели игроков.
#
# <b> Рейтинг игр от организации ESRB: </b>
#
#         Самые популярные игры по влиянию рейтинга ESRB:
#
#         Северной Америки - m(с 17 лет), t(с 13 лет), e(для всех), e10+(с 10 лет), rp(нет категории);
#
#         Европы - m(с 17 лет), e(для всех), t(с 13 лет), e10+(с 10 лет), rp(нет категории);
#
#         Японии - e(для всех), t(с 13 лет), m(с 17 лет), e10+(с 10 лет), rp(нет категории).
#
#     Из вышеизложенного можно отметить, что определённый вид рейтинга от этой организации влияет на продажи игр.
#
# <b> Были проверены две гипотезы: </b>
#
#         средние пользовательские рейтинги платформ Xbox One и PC одинаковые
#
#     Нулевая гипотеза была принята - средние рейтинги юзеров Xbox One и PC равны.
#
#         средние пользовательские рейтинги жанров Action и Sports разные
#
#     Нулевая гипотеза была опровергнута, поэтому принята альтернативная - средние рейтинги юзеров Action и Sports разные.
#
# <b> Из всего вышеперечисленного можно сделать такой общий вывод: </b>
#
#     Игра имеет больше шансов стать успешной, если:
#
#         - она выходит на ps4, ps3, wiiu или 3ds (и более новые версии платформ), а также на PC;
#         - она проходит по таким рейтингам, как - m(с 17 лет), e(для всех) и t(с 13 лет);
#         - её жанр можно определить как shooter, action и role-playing.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Выводы понятны и логичны, а самое главное подкреплены выявленными фактами.
#
# Ты очень серьезно подходишь к визуализации.
#
# Вот пара ссылок на полезные источники:https://habr.com/ru/company/otus/blog/540526/, https://pythonru.com/biblioteki/seaborn-plot
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
#
# Вау! Крутотень! Спасиби)))
#
# Не успела залезть и прочитать всё сверху-до низу, но изучу обязательно.
#
# Теперь дальше буду учиться делать красивое)
# </div>

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.1</b>
#
# 👋
# У тебя замечательная и очень сильная работа. Спасибо тебе большое, что ты уделяешь оформлению проекта особое внимание - ты не представляешь, как приятно не рыться в коде и не скролить туды сюды блокнот, чтобы найти какую-нибудь информацию. Каждый заголовок выделен, каждое рассуждение выделено, каждый пункт выделен. Так же мне очень понравилось, что тобой найдены все основные инсайты в данных, чательно обоснованы и с точки зрения кода проработаны достаточно оптимально.  Я оставил несколько обязательных поправок для тебя и после этого буду готов сразу принять проект.
#
# Удачи в доработках, жду!

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
#
# Теперь уже вроде всё красиво получилось.
# </div>

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.2</b>
#
# 👋
#
# Анна, спасибо тебе за исправления критических моментов, а также спасибо за хорошую работу.
#
# Поздравляю с успешным завершением проекта 😊👍
#
# И желаю успехов в новых работах 😊

# %% [markdown]
# ## Чек лист готовности проекта

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены
# - [x]  заменить названия столбцов (привести к нижнему регистру)
# - [x]  преобразовать данные в нужные типы. Описать, в каких столбцах я заменила тип данных и почему
# - [x]  обработать пропуски при необходимости и объяснить почему я сделала именно так или жэе почему не стала этого делать
# - [x]  описать причины, которые могли привести к пропускам
# - [x]  обратить внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей
# - [x]  посчитать суммарные продажи во всех регионах и записать их в отдельный столбец
# - [x]  сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# - [x]  как менялись продажи по платформам?
# - [x]  взять данные за соответствующий актуальный период
# - [x]  какие платформы лидируют по продажам, растут или падают? Выбрать несколько потенциально прибыльных платформ
# - [x]  построить боксплот по глобальным продажам игр в разбивке по платформам. Описать результат
# - [x]  посмотреть, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. сформулировать выводы
# - [x]  по общему распределению игр по жанрам сделать выводы по двум вопросам:
#         - Что можно сказать о самых прибыльных жанрах?
#         - Выделяются ли жанры с высокими и низкими продажами?
# - [x]  составить портрет пользователя каждого региона
#         - самые популярные платформы (топ-5). Описать различия в долях продаж.
#         - самые популярные жанры (топ-5). Пояснить разницу.
#         - влияет ли рейтинг ESRB на продажи в отдельном регионе?
# - [x]  проверить гипотезы
#         - средние пользовательские рейтинги платформ Xbox One и PC одинаковые
#         - средние пользовательские рейтинги жанров Action и Sports разные
#         - задать самостоятельно пороговое значение alpha
# - [x]  Пояснить:
#         - как я сформулировала нулевую и альтернативную гипотезы
#         - какой критерий применила для проверки гипотез и почему
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
